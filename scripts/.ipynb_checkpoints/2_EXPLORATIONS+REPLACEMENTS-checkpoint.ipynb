# %% [markdown]
# **Make sure that you are connected to the kernel associated with our virtual environment . Go to `Kernel` -> `Change kernel` and choose `pia_venv`.**

# %%
### REQUIREMENTS

import pandas as pd
import re

# %%
### load our data
c_aristotelicum = pd.read_json("../data/c_aristotelicum.json")
c_hippocraticum = pd.read_json("../data/c_hippocraticum.json")

# %% [markdown]
# # Key term replacement

# %%
### produce a list of all words from the authors
### (useful for a preliminary exploration)
aristotle_list = []
for list_element in c_aristotelicum["lemmata"].tolist():
  aristotle_list.extend(list_element)
hippocrates_list = []
for list_element in c_hippocraticum["lemmata"].tolist():
  hippocrates_list.extend(list_element)
one_merged_list = aristotle_list + hippocrates_list

# %%
# manually define key terms we are interested in:
keyterm_patterns = [("^λ[υ|ύ]π.+", "λύπ*"), ("[α|ά|ἀ|ἄ]λγ.+", "ἄλγ*"), ("^[ὀ|ὠ]δ[ύ|υ]ν.", "ὀδύν*"), ("^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+", "πόνο*")]

# %%
# unique word forms
matches = []
for pattern_tuple in keyterm_patterns:
  r = re.compile(pattern_tuple[0])
  matches.extend([(pattern_tuple[0], pattern_tuple[1], match, aristotle_list.count(match), hippocrates_list.count(match)) for match in list(filter(r.search, list(set(aristotle_list + hippocrates_list))))])
matches_df = pd.DataFrame(matches, columns=["pattern", "replacement", "match", "c_aristotelicum", "c_hippocraticum"]) #, "translation"])
matches_df
# Out:
#                             pattern replacement         match  \
# 0                        ^λ[υ|ύ]π.+        λύπ*        λυπέον
# 1                        ^λ[υ|ύ]π.+        λύπ*      λυπέοιτο
# 2                        ^λ[υ|ύ]π.+        λύπ*  λύπαςμεσότης
# 3                        ^λ[υ|ύ]π.+        λύπ*         λυπρᾷ
# 4                        ^λ[υ|ύ]π.+        λύπ*          λύπη
# ..                              ...         ...           ...
# 157  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*     πονέσωσιν
# 158  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*      πονέοντι
# 159  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*        πονέσῃ
# 160  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*      πονητέος
# 161  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*     πονέοντος
#
#      c_aristotelicum  c_hippocraticum
# 0                  0                8
# 1                  0                1
# 2                  1                0
# 3                  1                0
# 4                197               11
# ..               ...              ...
# 157                0                1
# 158                0                2
# 159                0                8
# 160                0                1
# 161                0                3
#
# [162 rows x 5 columns]

# %%
matches_ch = matches_df[matches_df["c_hippocraticum"]>0]
matches_ch
# Out:
#                             pattern replacement      match  c_aristotelicum  \
# 0                        ^λ[υ|ύ]π.+        λύπ*     λυπέον                0
# 1                        ^λ[υ|ύ]π.+        λύπ*   λυπέοιτο                0
# 4                        ^λ[υ|ύ]π.+        λύπ*       λύπη              197
# 6                        ^λ[υ|ύ]π.+        λύπ*   λυπέουσα                0
# 7                        ^λ[υ|ύ]π.+        λύπ*   λυπέοντα                0
# ..                              ...         ...        ...              ...
# 157  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*  πονέσωσιν                0
# 158  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*   πονέοντι                0
# 159  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*     πονέσῃ                0
# 160  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*   πονητέος                0
# 161  ^π[ό|ο]ν[ο|ό|έ|ε|η|ή|ῆ](?!ρ).+       πόνο*  πονέοντος                0
#
#      c_hippocraticum
# 0                  8
# 1                  1
# 4                 11
# 6                  1
# 7                  3
# ..               ...
# 157                1
# 158                2
# 159                8
# 160                1
# 161                3
#
# [134 rows x 5 columns]

# %%
matches_ch.to_csv("../data/matches_pain_words.csv")

# %%
# use these regular expressions to make replacements in the list of lemmata
def replacer_word_list(pattern, product, word_list):
  return [re.sub(pattern, product, word) for word in word_list]

def replace_keywords(list_of_words, list_of_tuples):
  for pattern in list_of_tuples:
    list_of_words = replacer_word_list(pattern[0], pattern[1], list_of_words)
  return list_of_words

# %%
### test (includes artificial words):
word_list_test = ['βοοκ', 'πᾶς', 'μέλυπρᾷ', "ἄλγτέχνη",'τέχνη' ,'πᾶς', 'μέθοδος', 'ὅμοιος', "λύπη",'πρᾶξίς', 'προαίρεσις', 'ἀγαθός', 'ἐφίημι']
replace_keywords(word_list_test, keyterm_patterns)
# Out:
# ['βοοκ',
#  'πᾶς',
#  'μέλυπρᾷ',
#  'ἄλγ*',
#  'τέχνη',
#  'πᾶς',
#  'μέθοδος',
#  'ὅμοιος',
#  'λύπ*',
#  'πρᾶξίς',
#  'προαίρεσις',
#  'ἀγαθός',
#  'ἐφίημι']

# %%
# apply the replacement on the level of individual words
c_aristotelicum["lemmata_repl"] = c_aristotelicum["lemmata"].apply(lambda x: replace_keywords(x, keyterm_patterns))
c_hippocraticum["lemmata_repl"] = c_hippocraticum["lemmata"].apply(lambda x: replace_keywords(x, keyterm_patterns))

# %%
# apply the replacement on the sentences
def replace_in_sentences(list_of_sentences):
    return [replace_keywords(sentence, keyterm_patterns) for sentence in list_of_sentences]

c_aristotelicum["lemmatized_sentences_repl"] = c_aristotelicum["lemmatized_sentences"].apply(replace_in_sentences)
c_hippocraticum["lemmatized_sentences_repl"] = c_hippocraticum["lemmatized_sentences"].apply(replace_in_sentences)

# %%
c_hippocraticum.head(5)
# Out:
#                              filename       author  \
# 1039  tlg0627.tlg001.perseus-grc1.xml  Hippocrates
# 1040  tlg0627.tlg002.perseus-grc1.xml  Hippocrates
# 1041  tlg0627.tlg003.perseus-grc1.xml  Hippocrates
# 1042  tlg0627.tlg004.perseus-grc1.xml  Hippocrates
# 1043  tlg0627.tlg005.perseus-grc1.xml  Hippocrates
#
#                               title  wordcount author_id          doc_id  \
# 1039            On Ancient Medicine       5534   tlg0627  tlg0627.tlg001
# 1040        De aere aquis et locis        7502   tlg0627  tlg0627.tlg002
# 1041       The Book of Prognostics        5217   tlg0627  tlg0627.tlg003
# 1042  On Regimen in Acute Diseases        6128   tlg0627  tlg0627.tlg004
# 1043                     Acut. sp.        5218   tlg0627  tlg0627.tlg005
#
#       raw_date  date_avr                  date_probs  date_manual provenience  \
# 1039  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}         -3.5       pagan
# 1040  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}         -3.5       pagan
# 1041  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}         -3.5       pagan
# 1042  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}         -3.5       pagan
# 1043  5-4 B.C.        -4  {'-4.5': 0.5, '-3.5': 0.5}         -3.5       pagan
#
#      tlg_epithet                                       clean_string  \
# 1039      Medici  ὁπόσοι μὲν ἐπεχείρησαν περὶ ἰητρικῆς λέγειν ἢ ...
# 1040      Medici  ἰητρικὴν ὅστις βούλεται ὀρθῶς ζητεῖν, τάδε χρὴ...
# 1041      Medici  τὸν ἰητρὸν δοκέει μοι ἄριστον εἶναι πρόνοιαν ἐ...
# 1042      Medici  οἱ ξυγγράψαντες τὰς Κνιδίας καλεομένας γνώμας,...
# 1043      Medici  καῦσος γίγνεται, ὁκόταν ἀναξηρανθέντα τὰ φλέβι...
#
#       n_sentences                               lemmatized_sentences  \
# 1039          258  [[ὁπόσος, ἐπιχειρέω, ἰητρικῆς, λέγω, γράφω, ὑπ...
# 1040          461  [[ἰατρικός, βούλομαι, ζητέω, χρή, ποιέω], [πρῶ...
# 1041          302  [[ἰατρός, δοκέω, ἀγαθός, εἰμί, πρόνοια, ἐπιτηδ...
# 1042          373  [[ξυγγράψαντες, Κνίδιος, καλέω, γνώμη, ὁποῖος,...
# 1043          352  [[καῦσος, γίγνομαι, ἀναξηρανθέντα, φλέβια, θερ...
#
#                                                 lemmata  lemmata_wordcount  \
# 1039  [ὁπόσος, ἐπιχειρέω, ἰητρικῆς, λέγω, γράφω, ὑπό...               2613
# 1040  [ἰατρικός, βούλομαι, ζητέω, χρή, ποιέω, πρῶτος...               3470
# 1041  [ἰατρός, δοκέω, ἀγαθός, εἰμί, πρόνοια, ἐπιτηδε...               2503
# 1042  [ξυγγράψαντες, Κνίδιος, καλέω, γνώμη, ὁποῖος, ...               2926
# 1043  [καῦσος, γίγνομαι, ἀναξηρανθέντα, φλέβια, θερι...               2855
#
#                                            lemmata_repl  \
# 1039  [ὁπόσος, ἐπιχειρέω, ἰητρικῆς, λέγω, γράφω, ὑπό...
# 1040  [ἰατρικός, βούλομαι, ζητέω, χρή, ποιέω, πρῶτος...
# 1041  [ἰατρός, δοκέω, ἀγαθός, εἰμί, πρόνοια, ἐπιτηδε...
# 1042  [ξυγγράψαντες, Κνίδιος, καλέω, γνώμη, ὁποῖος, ...
# 1043  [καῦσος, γίγνομαι, ἀναξηρανθέντα, φλέβια, θερι...
#
#                               lemmatized_sentences_repl
# 1039  [[ὁπόσος, ἐπιχειρέω, ἰητρικῆς, λέγω, γράφω, ὑπ...
# 1040  [[ἰατρικός, βούλομαι, ζητέω, χρή, ποιέω], [πρῶ...
# 1041  [[ἰατρός, δοκέω, ἀγαθός, εἰμί, πρόνοια, ἐπιτηδ...
# 1042  [[ξυγγράψαντες, Κνίδιος, καλέω, γνώμη, ὁποῖος,...
# 1043  [[καῦσος, γίγνομαι, ἀναξηρανθέντα, φλέβια, θερ...

# %% [markdown]
# # Export the data for future usage

# %%
c_hippocraticum.to_json("../data/c_hippocraticum_repl.json")
c_aristotelicum.to_json("../data/c_aristotelicum_repl.json")
