# %%
### PREREQUISTIES
### (many used only in one notebook...)

# common python libraries
import os
import pandas as pd
import numpy as np
import logging ### to monitor the code
from bs4 import BeautifulSoup
import pickle
import math
import random
import sys
import csv
import unicodedata
import requests
import re
import json

# plotting
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import seaborn as sns
from sklearn.manifold import TSNE

from scipy import stats

# data exchange with googlesheets
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.oauth2 import service_account # based on google-auth library

# data exchange with sciencedata
import sddk

# language data modeling with gensim
from gensim import corpora
from gensim import models

# language data modeling with sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.decomposition import TruncatedSVD  
from sklearn.metrics.pairwise import cosine_similarity

# %%
### not neccessary for reading the data, just for exporting data and especially plots to sciencedata.dk
conf = sddk.configure()
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# endpoint variable has been configured to: https://sciencedata.dk/files/

# %%
# to access gsheet, you need Google Service Account key json file
# I have mine located in my personal space on sciencedata.dk, so I read it from there:

# (1) read the file and parse its content
file_data = conf[0].get(conf[1] + "ServiceAccountsKey.json").json()
# (2) transform the content into crendentials object
credentials = service_account.Credentials.from_service_account_info(file_data)
# (3) specify your usage of the credentials
scoped_credentials = credentials.with_scopes(['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])
# (4) use the constrained credentials for authentication of gspread package
gc = gspread.Client(auth=scoped_credentials)
# (5) establish connection with spreadsheets specified by their url
PIA_data = gc.open_by_url("https://docs.google.com/spreadsheets/d/1KxOx7Be9fj3lDcEPgQhQ-Iqcn9p367-MMD6RMXe8rks/edit?usp=sharing")
PIA_overview = gc.open_by_url("https://docs.google.com/spreadsheets/d/1e94wyelg6dftQ4zxbq1xvwxWAI-BhcYXtclDW-YTnrw/edit?usp=sharing")

# %% [markdown]
# # Import corpus

# %%
# import preprocessed data corpora from a public folder on sciencedata
publicfolder = "31b393e2afe1ee96ce81869c7efe18cb"
c_hippocraticum = sddk.read_file("c_hippocraticum_enriched.json", "df", publicfolder)
# Out:
# reading file located in a public folder

# %%
# function to extract all texts into one list of sentences
def get_flat_sentences(series):
    sentences_list = [sent for doc in series.tolist() for sent in doc]
    return sentences_list

# %%
# use the function
docs = get_flat_sentences(c_hippocraticum["lemmatized_sentences_repl"])

# %%
# number of sentences
len(docs)
# Out:
# 24456

# %%
# look at first 10 sentences
print(docs[:10])
# Out:
# [['ὁπόσος', 'ἐπιχειρέω', 'ἰητρικῆς', 'λέγω', 'γράφω', 'ὑπόθεσις', 'αὐτός', 'ὑποθέμενοι', 'λόγος', 'θερμός', 'ψυχρός', 'ὑγρός', 'ξηρός', 'ἄλλος', 'ἐθέλω', 'βραχύς', 'ἄγω', 'ἀρχή', 'αἰτία', 'ἄνθρωπος', 'νοῦσος', 'θάνατος', 'πᾶς', 'αὐτός', 'εἷς', 'ὑποθέμενοι', 'πολύς', 'λέγω', 'καταφανής', 'εἰμί', 'ἁμαρτάνω', 'ἄξιος', 'μέμφομαι', 'τέχνη', 'εἰμί', 'χράω', 'πᾶς', 'μέγας', 'τιμάω', 'ἀγαθός', 'χειροτέχνης', 'δημιουργός'], ['δημιουργός', 'φαῦλος', 'πολύς', 'διαφέροντες'], ['εἰμί', 'ἰατρικός', 'αὐτός', 'ἔσκεπτο', 'εὑρίσκω', 'μηδείς', 'εἰμί', 'πᾶς', 'ἄπειρος', 'ἀνεπιστήμων', 'εἰμί', 'τύχη', 'κάμνω', 'διοικεῖτο'], ['ἔχω', 'ἄλλος', 'τέχνη', 'δημιουργός', 'πολύς', 'διαφέρω', 'χείρ', 'γνώμη', 'ἰητρικῆς'], ['ἀξιόω', 'κενός', 'ὑπόθεσις', 'δέω', 'ἀφανέα', 'ἀπορεόμενα', 'ἀνάγκη', 'ἐπιχειρέω', 'λέγω', 'ὑπόθεσις', 'χράω', 'οἷος', 'μετέωρος', 'γῆ'], ['τὶς', 'λέγω', 'γιγνώσκω', 'ἔχω', 'λέγω', 'ἀκούω', 'δῆλος', 'εἰμί', 'ἀληθής', 'εἰμί'], ['χρή', 'ἀνενέγκαντα', 'οἶδα', 'σαφής'], ['ἰατρικός', 'πᾶς', 'ὑπάρχω', 'ἀρχή', 'ὁδός', 'εὑρημένη', 'εὑρημένα', 'πολύς', 'ἔχω', 'εὑρίσκω', 'πολύς', 'χρόνος', 'λοιπός', 'εὑρίσκω', 'ἱκανός', 'εὑρημένα', 'οἶδα', 'οὗτος', 'ὁρμάω', 'ζητέω'], ['οὗτος', 'ἀποβάλλω', 'ἀποδοκιμάω', 'πᾶς', 'ἕτερος', 'ὁδός', 'ἕτερος', 'σχῆμα', 'ἐπιχειρέω', 'ζητέω', 'φημί', 'ἐξευρίσκω', 'ἐξαπατάω', 'ἐξαπατάω'], ['ἀδύνατος']]

# %% [markdown]
# # Matrices & vectors with sklearn

# %%
# build gensim dictionary on the basis of whole works
lemmata = c_hippocraticum["lemmata_repl"].tolist()
dictionary = corpora.Dictionary(lemmata)
# words in at least 5 works
# (in tuple with the number of sentences in which they appear)
dictionary_tup = [(len([doc for doc in docs if dictionary[word_id] in doc]), dictionary[word_id]) for word_id in dictionary if dictionary.dfs[word_id] >= 5]
#n=2000 # n sorted words with highest frequency
vocabulary = [tup[1] for tup in sorted(dictionary_tup, reverse=True)] #[:n]]
doc_freq = [tup[0] for tup in sorted(dictionary_tup, reverse=True)] #[:n]]

# %%
len(vocabulary)
# Out:
# 2032

# %%
sorted(dictionary_tup, reverse=True)[:10]
# Out:
# [(3315, 'εἰμί'),
#  (2829, 'γίγνομαι'),
#  (2351, 'οὗτος'),
#  (2103, 'πολύς'),
#  (1775, 'ἔχω'),
#  (1224, 'ἄλλος'),
#  (1169, 'σῶμα'),
#  (1129, 'ποιέω'),
#  (1030, 'χρή'),
#  (1010, 'αὐτός')]

# %%
len(vocabulary)
# Out:
# 2032

# %%
# check whether key_words are in vocabulary
key_words = ['πόνο*', 'ὀδύν*', 'ἄλγ*', 'λύπ*']
for word in key_words:
    if word in vocabulary:
        print(word)
# Out:
# πόνο*
# ὀδύν*
# ἄλγ*
# λύπ*

# %%
# check first 10 words in the vocabulary
vocabulary[:10]
# Out:
# ['εἰμί',
#  'γίγνομαι',
#  'οὗτος',
#  'πολύς',
#  'ἔχω',
#  'ἄλλος',
#  'σῶμα',
#  'ποιέω',
#  'χρή',
#  'αὐτός']

# %%
# check first sentence
docs[0]
# Out:
# ['ὁπόσος',
#  'ἐπιχειρέω',
#  'ἰητρικῆς',
#  'λέγω',
#  'γράφω',
#  'ὑπόθεσις',
#  'αὐτός',
#  'ὑποθέμενοι',
#  'λόγος',
#  'θερμός',
#  'ψυχρός',
#  'ὑγρός',
#  'ξηρός',
#  'ἄλλος',
#  'ἐθέλω',
#  'βραχύς',
#  'ἄγω',
#  'ἀρχή',
#  'αἰτία',
#  'ἄνθρωπος',
#  'νοῦσος',
#  'θάνατος',
#  'πᾶς',
#  'αὐτός',
#  'εἷς',
#  'ὑποθέμενοι',
#  'πολύς',
#  'λέγω',
#  'καταφανής',
#  'εἰμί',
#  'ἁμαρτάνω',
#  'ἄξιος',
#  'μέμφομαι',
#  'τέχνη',
#  'εἰμί',
#  'χράω',
#  'πᾶς',
#  'μέγας',
#  'τιμάω',
#  'ἀγαθός',
#  'χειροτέχνης',
#  'δημιουργός']

# %%
# SIMPLE TEST
# (by default, countvectorizers does some undesirable preprocessing (e.g. removes *....))
test_corpus =  [['δῆμος*', 'Ἀθηναῖος','φαίνω','Ἕλλην', 'φαίνω'], ['δοκέω','οὗτος','τέχνη','ἐμός']]
vec_bow = CountVectorizer(lowercase=False, token_pattern=r"\w+\*?") #vocabulary=vocabulary, token_pattern=r".?\w+\*?") #, #strip_accents=None, encoding="utf-8") #, token_pattern=r"\*?\w+\*?")
bow = vec_bow.fit_transform([" ".join(list(set(sentence))) for sentence in test_corpus]) ### run the model
vec_bow.get_feature_names()
# Out:
# ['δοκέω', 'δῆμος*', 'οὗτος', 'τέχνη', 'φαίνω', 'Ἀθηναῖος', 'ἐμός', 'Ἕλλην']

# %%
# we create CountVectorizor model with our predefined vocabulary
# we are explict about prepreprocessing of the textual data
vec_bow = CountVectorizer(vocabulary=vocabulary, lowercase=False, token_pattern=r"\w+\*?") #vocabulary=vocabulary, token_pattern=r".?\w+\*?") #, #strip_accents=None, encoding="utf-8") #, token_pattern=r"\*?\w+\*?")
# we fit our sentences to the model
# -> we create a raw document-term matrix:
# notice that we calculate only unique instances of words within sentences 
# (that makes more straightforward an interpretation in terms of probability)
bow = vec_bow.fit_transform([" ".join(list(set(sentence))) for sentence in docs])

# by multiplication, we create a word-word co-occurrence matrix:
cooc  = bow.T * bow

# we use previously calculated frequencies to fill in the diagonal:
cooc.setdiag(doc_freq) 
# transform it into a dataframe
# all counts (diagonal) and co-occurrences are weighted by the number of documents
cooc_df = pd.DataFrame(cooc.todense() / len(docs), columns=vocabulary, index=vocabulary) # / len(docs)
cooc_df
# Out:
# /home/kasev/.local/lib/python3.6/site-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#                εἰμί  γίγνομαι     οὗτος     πολύς       ἔχω     ἄλλος  \
# εἰμί       0.135550  0.018646  0.018073  0.016070  0.013575  0.010590
# γίγνομαι   0.018646  0.115677  0.016233  0.015947  0.009200  0.007851
# οὗτος      0.018073  0.016233  0.096132  0.010918  0.008791  0.006747
# πολύς      0.016070  0.015947  0.010918  0.085991  0.009895  0.006829
# ἔχω        0.013575  0.009200  0.008791  0.009895  0.072579  0.005970
# ...             ...       ...       ...       ...       ...       ...
# εὐεξίη     0.000123  0.000000  0.000041  0.000041  0.000041  0.000041
# διηγέομαι  0.000082  0.000082  0.000000  0.000041  0.000041  0.000000
# διαῤῥοίῃ   0.000000  0.000041  0.000000  0.000000  0.000041  0.000041
# διαχωρέῃ   0.000082  0.000041  0.000000  0.000041  0.000000  0.000000
# βῆχας      0.000041  0.000082  0.000041  0.000041  0.000000  0.000000
#
#                σῶμα     ποιέω       χρή     αὐτός  ...     κωφός     κλίνω  \
# εἰμί       0.009446  0.006829  0.008423  0.008955  ...  0.000082  0.000041
# γίγνομαι   0.010222  0.004498  0.003394  0.006910  ...  0.000082  0.000041
# οὗτος      0.004743  0.007442  0.005438  0.004171  ...  0.000000  0.000000
# πολύς      0.007197  0.004661  0.004498  0.004580  ...  0.000000  0.000000
# ἔχω        0.006379  0.003312  0.005193  0.004539  ...  0.000000  0.000082
# ...             ...       ...       ...       ...  ...       ...       ...
# εὐεξίη     0.000082  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# διηγέομαι  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# διαῤῥοίῃ   0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# διαχωρέῃ   0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# βῆχας      0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
#
#            καταπαύω  καταπίπτω   θόρυβος    εὐεξίη  διηγέομαι  διαῤῥοίῃ  \
# εἰμί       0.000000   0.000164  0.000000  0.000123   0.000082  0.000000
# γίγνομαι   0.000082   0.000000  0.000041  0.000000   0.000082  0.000041
# οὗτος      0.000000   0.000000  0.000000  0.000041   0.000000  0.000000
# πολύς      0.000041   0.000000  0.000000  0.000041   0.000041  0.000000
# ἔχω        0.000000   0.000041  0.000000  0.000041   0.000041  0.000041
# ...             ...        ...       ...       ...        ...       ...
# εὐεξίη     0.000000   0.000000  0.000000  0.000204   0.000000  0.000000
# διηγέομαι  0.000000   0.000000  0.000000  0.000000   0.000204  0.000000
# διαῤῥοίῃ   0.000000   0.000000  0.000000  0.000000   0.000000  0.000204
# διαχωρέῃ   0.000000   0.000000  0.000000  0.000000   0.000000  0.000000
# βῆχας      0.000000   0.000000  0.000000  0.000000   0.000000  0.000000
#
#            διαχωρέῃ     βῆχας
# εἰμί       0.000082  0.000041
# γίγνομαι   0.000041  0.000082
# οὗτος      0.000000  0.000041
# πολύς      0.000041  0.000041
# ἔχω        0.000000  0.000000
# ...             ...       ...
# εὐεξίη     0.000000  0.000000
# διηγέομαι  0.000000  0.000000
# διαῤῥοίῃ   0.000000  0.000000
# διαχωρέῃ   0.000204  0.000000
# βῆχας      0.000000  0.000204
#
# [2032 rows x 2032 columns]

# %% [markdown]
# Thus, we have a word-word co-occurrence table with co-occurrences weighted by the number of sentences, i.e. potential events of co-occurrences. That makes an interpretation in terms of probability very straightforward.

# %%
# now we transform the co-occurrences into PMI2

pmi_rows_list = []
for column in cooc_df.columns:
    freq_a = cooc_df.at[column, column]
    pmi_row = []
    for term in cooc_df.index:
        freq_ab = cooc_df.at[column, term]
        if freq_ab > 0:
            freq_ab = freq_ab **3
            freq_b = cooc_df.at[term, term]
            pmi2 = math.log(freq_ab / (freq_a * freq_b))
        else:
            pmi2 = None
        pmi_row.append(pmi2)
    pmi_rows_list.append(pmi_row)

# %%
pmi_matrix = pd.DataFrame(pmi_rows_list, columns=vocabulary, index=vocabulary)

# %%
pmi_matrix_df = pd.DataFrame(pmi_matrix)
pmi_matrix_df
# Out:
#                 εἰμί   γίγνομαι      οὗτος      πολύς        ἔχω      ἄλλος  \
# εἰμί       -1.998418  -7.791044  -7.699510  -7.940535  -8.276995  -8.650239
# γίγνομαι   -7.791044  -2.156952  -7.863097  -7.804989  -9.285564  -9.389703
# οὗτος      -7.699510  -7.863097  -2.342035  -8.756601  -9.236869  -9.659270
# πολύς      -7.940535  -7.804989  -8.756601  -2.453511  -8.770494  -9.511649
# ἔχω        -8.276995  -9.285564  -9.236869  -8.770494  -2.623075  -9.745246
# ...              ...        ...        ...        ...        ...        ...
# εὐεξίη    -16.524445        NaN -19.476665 -19.365189 -19.195624 -18.823948
# διηγέομαι -17.740840 -17.582306        NaN -19.365189 -19.195624        NaN
# διαῤῥοίῃ         NaN -19.661747        NaN        NaN -19.195624 -18.823948
# διαχωρέῃ  -17.740840 -19.661747        NaN -19.365189        NaN        NaN
# βῆχας     -19.820282 -17.582306 -19.476665 -19.365189        NaN        NaN
#
#                 σῶμα      ποιέω        χρή      αὐτός  ...      κωφός  \
# εἰμί       -8.947495  -9.885950  -9.164529  -8.961334  ... -17.740840
# γίγνομαι   -8.551831 -10.979956 -11.733102  -9.580319  ... -17.582306
# οὗτος     -10.670360  -9.284294 -10.133494 -10.910014  ...        NaN
# πολύς      -9.308203 -10.576243 -10.591624 -10.517960  ...        NaN
# ἔχω        -9.500523 -11.431927  -9.990939 -10.375302  ...        NaN
# ...              ...        ...        ...        ...  ...        ...
# εὐεξίη    -16.698531        NaN        NaN        NaN  ...        NaN
# διηγέομαι        NaN        NaN        NaN        NaN  ...        NaN
# διαῤῥοίῃ         NaN        NaN        NaN        NaN  ...        NaN
# διαχωρέῃ         NaN        NaN        NaN        NaN  ...        NaN
# βῆχας            NaN        NaN        NaN        NaN  ...        NaN
#
#                κλίνω   καταπαύω  καταπίπτω    θόρυβος     εὐεξίη  διηγέομαι  \
# εἰμί      -19.820282        NaN -15.661399        NaN -16.524445 -17.740840
# γίγνομαι  -19.661747 -17.582306        NaN -19.661747        NaN -17.582306
# οὗτος            NaN        NaN        NaN        NaN -19.476665        NaN
# πολύς            NaN -19.365189        NaN        NaN -19.365189 -19.365189
# ἔχω       -17.116183        NaN -19.195624        NaN -19.195624 -19.195624
# ...              ...        ...        ...        ...        ...        ...
# εὐεξίη           NaN        NaN        NaN        NaN  -8.495193        NaN
# διηγέομαι        NaN        NaN        NaN        NaN        NaN  -8.495193
# διαῤῥοίῃ         NaN        NaN        NaN        NaN        NaN        NaN
# διαχωρέῃ         NaN        NaN        NaN        NaN        NaN        NaN
# βῆχας            NaN        NaN        NaN        NaN        NaN        NaN
#
#             διαῤῥοίῃ   διαχωρέῃ      βῆχας
# εἰμί             NaN -17.740840 -19.820282
# γίγνομαι  -19.661747 -19.661747 -17.582306
# οὗτος            NaN        NaN -19.476665
# πολύς            NaN -19.365189 -19.365189
# ἔχω       -19.195624        NaN        NaN
# ...              ...        ...        ...
# εὐεξίη           NaN        NaN        NaN
# διηγέομαι        NaN        NaN        NaN
# διαῤῥοίῃ   -8.495193        NaN        NaN
# διαχωρέῃ         NaN  -8.495193        NaN
# βῆχας            NaN        NaN  -8.495193
#
# [2032 rows x 2032 columns]

# %% [markdown]
# our data are results of an algorithm to values lower than 1, what basicially implies negative numbers (see image below). Since this is not so well readible and interpretable, we will normalize these data to the scale from
#
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb
0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
#
#            καταπαύω  καταπίπτω   θόρυβος    εὐεξίη  διηγέομαι  διαῤῥοίῃ  \
# εἰμί       0.000000   0.695090  0.000000  0.675830   0.648684  0.000000
# γίγνομαι   0.652222   0.000000  0.605817  0.000000   0.652222  0.605817
# οὗτος      0.000000   0.000000  0.000000  0.609947   0.000000  0.000000
# πολύς      0.612435   0.000000  0.000000  0.612435   0.612435  0.000000
# ἔχω        0.000000   0.616219  0.000000  0.616219   0.616219  0.616219
# ...             ...        ...       ...       ...        ...       ...
# εὐεξίη     0.000000   0.000000  0.000000  0.855015   0.000000  0.000000
# διηγέομαι  0.000000   0.000000  0.000000  0.000000   0.855015  0.000000
# διαῤῥοίῃ   0.000000   0.000000  0.000000  0.000000   0.000000  0.855015
# διαχωρέῃ   0.000000   0.000000  0.000000  0.000000   0.000000  0.000000
# βῆχας      0.000000   0.000000  0.000000  0.000000   0.000000  0.000000
#
#            διαχωρέῃ     βῆχας
# εἰμί       0.648684  0.602279
# γίγνομαι   0.605817  0.652222
# οὗτος      0.000000  0.609947
# πολύς      0.612435  0.612435
# ἔχω        0.000000  0.000000
# ...             ...       ...
# εὐεξίη     0.000000  0.000000
# διηγέομαι  0.000000  0.000000
# διαῤῥοίῃ   0.000000  0.000000
# διαχωρέῃ   0.855015  0.000000
# βῆχας      0.000000  0.855015
#
# [2032 rows x 2032 columns]

# %%
keyterms_pmi_20 = {}
for keyterm in key_words:
    keyterms_pmi_20[keyterm] = keyterm_pmi_20_words = pmi_matrix_norm_df.sort_values(keyterm, ascending=False).index[1:21].tolist()
    keyterms_pmi_20[keyterm + " PPMI3"] = pmi_matrix_norm_df.sort_values(keyterm, ascending=False)[keyterm].tolist()[1:21]
    #keyterms_pmi_20.extend([keyterm_pmi_20_words, keyterm_pmi_20_values])   #, ascending=False) # ["πόνο*"][:10]

# %%
keyterms_pmi_20_df = pd.DataFrame(keyterms_pmi_20)
keyterms_pmi_20_df
# Out:
#        πόνο*  πόνο* PPMI3      ὀδύν*  ὀδύν* PPMI3      ἄλγ*  ἄλγ* PPMI3  \
# 0   γίγνομαι     0.822489        ἔχω     0.847966     ὀσφῦς    0.821130
# 1       σῶμα     0.819155    πυρετός     0.845206   πυρετός    0.812935
# 2      πολύς     0.815084       ἰξύς     0.842909    κεφαλή    0.808922
# 3    πυρετός     0.799087   γίγνομαι     0.838831     ὀδύν*    0.802402
# 4       εἰμί     0.798806     γαστήρ     0.837593       ἔχω    0.788007
# 5        ἔχω     0.792046       ἴσχω     0.831276    γαστήρ    0.784514
# 6     παρέχω     0.789773     κενεών     0.825334      ἰξύς    0.783206
# 7      ἄλλος     0.788714     κεφαλή     0.824908    κοιλία    0.782461
# 8        πᾶς     0.783869     παρέχω     0.821095  γίγνομαι    0.777604
# 9     κοιλία     0.783689      πολύς     0.814649      εἰμί    0.774067
# 10    χρόνος     0.782565      ῥῖγος     0.812630     νῶτον    0.770895
# 11    σιτίον     0.781249       ὀξύς     0.809699   πλευροῦ    0.770515
# 12     οὗτος     0.780738        βήξ     0.808945      ἴσχω    0.767116
# 13     ὀσφῦς     0.774672       παύω     0.808021    κενεών    0.761277
# 14      σάρξ     0.772903       εἰμί     0.807093  τράχηλος    0.759811
# 15   ἰσχυρός     0.772200     στῆθος     0.803635     οὗτος    0.758416
# 16    πλείων     0.770661       ἄλγ*     0.802402    στῆθος    0.750762
# 17       βήξ     0.770601  χλιάσματα     0.801548      χολή    0.750145
# 18     σῖτος     0.767897     κοιλία     0.799506  ὀλέθριος    0.749993
# 19      αἷμα     0.763364    πλευρόν     0.798492   πλευρόν    0.749840
#
#          λύπ*  λύπ* PPMI3
# 0        εἰμί    0.754913
# 1    συμβαίνω    0.742788
# 2    ἄνθρωπος    0.740049
# 3    γίγνομαι    0.737130
# 4     φυσᾶται    0.731851
# 5        ἀλύω    0.728871
# 6       αὐτός    0.728649
# 7      οὐδείς    0.723645
# 8       ἡδονή    0.716382
# 9   ἐξέρχομαι    0.712993
# 10   οἰδέουσι    0.712050
# 11     κρύπτω    0.710774
# 12       σῶμα    0.710447
# 13      οὗτος    0.709794
# 14      χροιά    0.709611
# 15    πάρειμι    0.706371
# 16       αἴρω    0.706296
# 17     ὀλίγος    0.704736
# 18   πρόσωπον    0.704080
# 19    προσήκω    0.703443

# %%
pmi_words = []
for keyword in key_words:
    pmi_words.extend(keyterms_pmi_20_df[keyword].tolist())
ppmi3_unique_words = list(set(pmi_words))
print(ppmi3_unique_words)
# Out:
# ['πυρετός', 'ὀσφῦς', 'νῶτον', 'γίγνομαι', 'φυσᾶται', 'πᾶς', 'ἰσχυρός', 'σάρξ', 'ἀλύω', 'πλείων', 'πάρειμι', 'γαστήρ', 'αἴρω', 'ἡδονή', 'ἔχω', 'τράχηλος', 'κρύπτω', 'κεφαλή', 'οἰδέουσι', 'προσήκω', 'ἄλγ*', 'βήξ', 'οὗτος', 'εἰμί', 'συμβαίνω', 'αὐτός', 'κενεών', 'πλευρόν', 'ὀλέθριος', 'πλευροῦ', 'οὐδείς', 'ὀλίγος', 'ὀδύν*', 'ἰξύς', 'στῆθος', 'χολή', 'σῶμα', 'σῖτος', 'χροιά', 'ῥῖγος', 'αἷμα', 'κοιλία', 'σιτίον', 'πρόσωπον', 'πολύς', 'ἐξέρχομαι', 'ὀξύς', 'ἄνθρωπος', 'χλιάσματα', 'χρόνος', 'παρέχω', 'παύω', 'ἄλλος', 'ἴσχω']

# %%
# read manually coded colors
terms_by_cat_df = get_as_dataframe(PIA_overview.worksheet("terms_by_cat"))
terms_by_cat_dict = dict(zip(terms_by_cat_df["term"], terms_by_cat_df["term_category"]))

uncoded = [word for word in pmi_words if word not in terms_by_cat_dict.keys()]
print(uncoded)
# Out:
# []

# %%
# if we need to translate any term
publicfolder = "8fe7d59de1eafe5f8eaebc0044534606"
morpheus_by_lemma = json.loads(requests.get("https://sciencedata.dk/public/" + publicfolder + "/morpheus_by_lemma.json").content)
morpheus_dict = json.loads(requests.get("https://sciencedata.dk/public/" + publicfolder + "/morpheus_dict.json").content)

# %%
# read manually coded colors
terms_by_cat_df = get_as_dataframe(PIA_overview.worksheet("terms_by_cat"))
terms_by_cat_dict = dict(zip(terms_by_cat_df["term"], terms_by_cat_df["term_category"]))

# manually define category-color pairs
cat_colors_dict = {'general term': 'gray',
 'pain-word': 'black',
 'pathological state': 'red',
 'body and its parts': 'darkorange',
 'perception and emotion' : 'blue',
 'dietetic term': 'green',
 'quality': 'purple'}
terms_by_col_dict = {}
for key in terms_by_cat_dict.keys():
    #print(key)
    terms_by_col_dict[key] = cat_colors_dict[terms_by_cat_dict[key]]
    
#plt.rcParams['figure.figsize'] = [12, 4]
fig, axs = plt.subplots(1, 4, figsize=[12,4], tight_layout=True)

for word, ax in zip(key_words, axs):
    xcol = keyterms_pmi_20_df[word + " PPMI3"]
    ycol = keyterms_pmi_20_df[word]
    actual_colors = [terms_by_col_dict[word] for word in ycol]
    sns.barplot(x=xcol, y=ycol, palette=actual_colors, ax=ax)
    ax.set(ylabel="", xlabel="Terms with highest PPMI$^3$ \nassociation with " + word)
    ax.set_xticks([0, 0.5, 1])
    ax.set_xlim(0, 1)
plt.subplots_adjust(hspace=0.08) # top=1, bottom=0, left=0, right=1, hspace=0.08, wspace=1.2)

#plt.title("Most frequent terms in sentences containing pain-words                       ", loc="right")

markers = [plt.Line2D([0,0],[0,0],color=color, marker="s", linestyle="") for color in cat_colors_dict.values()]
plt.legend(markers, cat_colors_dict.keys(), numpoints=1,  title="Term categories", bbox_to_anchor=(1, 1), loc='upper left')

# %%
sddk.write_file("public_data/PIA/ppmi3_painwords.png", fig, conf)
# Out:
# A file with the same name ("ppmi3_painwords.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/public_data/PIA/ppmi3_painwords.png"

# %% [markdown]
# # Tructated SVD

# %%
# takes some time, because of the high number of iterations
svd = TruncatedSVD(n_components=250, random_state=1, n_iter=200)
pmi_svd = svd.fit_transform(pmi_matrix_norm_df)

# %%
pmi_svd_df = pd.DataFrame(pmi_svd, index=vocabulary)
pmi_svd_df
# Out:
#                  0         1          2         3         4         5    \
# εἰμί       23.493198 -0.926991  13.555652  1.230634  0.377274  0.765865
# γίγνομαι   22.325499 -2.220492  12.214023 -0.069626 -0.420403  0.717086
# οὗτος      21.712296 -0.058491  11.478168  1.923566  0.482506  0.815276
# πολύς      21.964819 -0.837514  11.723856  0.814177 -0.633200  1.231174
# ἔχω        21.531860 -0.647536  11.092578  0.251080  0.236791  0.406295
# ...              ...       ...        ...       ...       ...       ...
# εὐεξίη      1.022724 -0.309498  -0.950797  0.229229 -0.051627  0.210875
# διηγέομαι   1.065802 -0.010151  -0.790902  0.458204 -0.106697  0.083055
# διαῤῥοίῃ    0.654703  0.142801  -0.459787  0.206244 -0.173547  0.195980
# διαχωρέῃ    0.963469  0.030426  -0.582341 -0.455397 -0.424855  0.345645
# βῆχας       0.824848 -0.387440  -0.481549 -0.001440 -0.229261  0.074253
#
#                 6         7         8         9    ...       240       241  \
# εἰμί       0.319402  2.987963  1.606221  4.858758  ...  0.361872 -0.413970
# γίγνομαι  -0.356604  2.803927  2.060188  3.822865  ...  0.564947  0.424787
# οὗτος     -0.070575  2.533954  1.301374  3.766946  ... -0.673433 -0.710603
# πολύς      0.582388  1.968977  1.522934  3.957256  ... -0.028290 -0.806354
# ἔχω        0.435036  1.702102  0.411445  3.664785  ... -0.590212 -0.161716
# ...             ...       ...       ...       ...  ...       ...       ...
# εὐεξίη     0.176525  0.328145  0.116688  0.390974  ...  0.137878  0.104974
# διηγέομαι -0.243463  0.039141 -0.133557  0.430330  ...  0.075144  0.189033
# διαῤῥοίῃ   0.117939 -0.138800  0.190403  0.240794  ...  0.126893 -0.092002
# εὐεξίη     0.256212  0.236896  0.225144  0.206293  ...  0.268481  0.271648
# διηγέομαι  0.215998  0.217045  0.237830  0.205559  ...  0.373431  0.190408
# διαῤῥοίῃ   0.189356  0.197302  0.189506  0.183032  ...  0.181075  0.212124
# διαχωρέῃ   0.190433  0.210394  0.222788  0.219604  ...  0.111978  0.185255
# βῆχας      0.234048  0.218274  0.190862  0.224630  ...  0.248703  0.196467
#
#            καταπαύω  καταπίπτω   θόρυβος    εὐεξίη  διηγέομαι  διαῤῥοίῃ  \
# εἰμί       0.224710   0.230394  0.195981  0.206564   0.217487  0.181452
# γίγνομαι   0.248446   0.213621  0.219981  0.197107   0.215564  0.209506
# οὗτος      0.227792   0.230830  0.180490  0.227784   0.207512  0.177114
# πολύς      0.256814   0.227929  0.198985  0.214848   0.223506  0.178142
# ἔχω        0.241859   0.252649  0.185555  0.220914   0.235282  0.203465
# ...             ...        ...       ...       ...        ...       ...
# εὐεξίη     0.248810   0.244009  0.057867  1.000000   0.255466  0.284139
# διηγέομαι  0.192261   0.259142  0.103891  0.255466   1.000000  0.306542
# διαῤῥοίῃ   0.117773   0.273050  0.095110  0.284139   0.306542  1.000000
# διαχωρέῃ   0.154183   0.118951  0.026152  0.293406   0.175361  0.055429
# βῆχας      0.265400   0.111574  0.048512  0.291114   0.249249  0.196459
#
#            διαχωρέῃ     βῆχας
# εἰμί       0.205786  0.206974
# γίγνομαι   0.211727  0.220640
# οὗτος      0.203699  0.221280
# πολύς      0.215929  0.224741
# ἔχω        0.218819  0.210829
# ...             ...       ...
# εὐεξίη     0.293406  0.291114
# διηγέομαι  0.175361  0.249249
# διαῤῥοίῃ   0.055429  0.196459
# διαχωρέῃ   1.000000  0.237685
# βῆχας      0.237685  1.000000
#
# [2032 rows x 2032 columns]

# %%
pmi_svd_cos_pain = {}
for key_word in key_words: 
    ordered_df = pmi_svd_cos.sort_values(key_word, ascending=False)
    pmi_svd_cos_pain[key_word + " word"] = ordered_df.index.tolist()[1:21]
    pmi_svd_cos_pain[key_word + " cos.sim."] = ordered_df[key_word].tolist()[1:21]

# %%
pmi_svd_cos_pain_df = pd.DataFrame(pmi_svd_cos_pain)
pmi_svd_cos_pain_df
# Out:
#    πόνο* word  πόνο* cos.sim. ὀδύν* word  ὀδύν* cos.sim. ἄλγ* word  \
# 0       πολύς        0.795760    πυρετός        0.810636     ὀδύν*
# 1    γίγνομαι        0.784638   γίγνομαι        0.799039   πυρετός
# 2         ἔχω        0.780508        ἔχω        0.794110    κεφαλή
# 3        εἰμί        0.776276      πολύς        0.776073     ῥῖγος
# 4        σῶμα        0.775370       εἰμί        0.775236    γαστήρ
# 5       ἄλλος        0.765793     κεφαλή        0.767290  ὀφθαλμός
# 6     πυρετός        0.762516      οὗτος        0.763422      ὀξύς
# 7      κοιλία        0.751712     γαστήρ        0.754768       ἔχω
# 8       οὗτος        0.745031       ἄλγ*        0.752924     πόνο*
# 9       νόσος        0.741550       αἷμα        0.742004      ἴσχω
# 10        πᾶς        0.729636     κοιλία        0.737893   σκληρός
#     ἄλγ* cos.sim.  λύπ* word  λύπ* cos.sim.
# 0        0.752924     ἐρωτάω       0.611498
# 1        0.730869      χροιά       0.601709
# 2        0.712098   συμβαίνω       0.588504
# 3        0.709654       ψαύω       0.587772
# 4        0.709169  σπλάγχνον       0.581721
# 5        0.703846       ὅρος       0.580897
# 6        0.701693   ἀνίστημι       0.579791
# 7        0.701172    βληχρός       0.576569
# 8        0.698251       ἄλγ*       0.570812
# 9        0.697120  ἐξέρχομαι       0.568630
# 10       0.683900   ἀποκρίνω       0.568127
# 11       0.683624      παχύς       0.566997
# 12       0.679478      πότος       0.565378
# 13       0.676471       γονή       0.564326
# 14       0.675721       αἴρω       0.563891
# 15       0.675364       ὁράω       0.559727
# 16       0.675050    ἔρχομαι       0.555204
# 17       0.671625   πρόσωπον       0.553506
# 18       0.669362      πνίγω       0.551393
# 19       0.665613     ψυχρός       0.550918

# %%
words = []
for key_word in key_words:
    words.extend(pmi_svd_cos_pain_df[key_word + " word"].tolist())
ppmi3svd_unique_words = list(set(words))
len(ppmi3svd_unique_words)
# Out:
# 51

# %%
terms_by_cat_df = get_as_dataframe(PIA_overview.worksheet("terms_by_cat"))
terms_by_cat_dict = dict(zip(terms_by_cat_df["term"], terms_by_cat_df["term_category"]))

# %%
for term in ppmi3svd_unique_words:
    if term not in terms_by_cat_dict.keys():
        print(morpheus_by_lemma[term])

# %%
term_cats = list(set(terms_by_cat_dict.values()))
term_cats
# Out:
# ['body and its parts',
#  'quality',
#  'general term',
#  'pain-word',
#  'pathological state',
#  'dietetic term',
#  'perception and emotion']

# %%
#plt.rcParams['figure.figsize'] = [12, 4]
fig, axs = plt.subplots(1, 4, figsize=[12,4], tight_layout=True)

# manually define category-color pairs
cat_colors_dict = {'general term': 'gray',
 'pain-word': 'black',
 'pathological state': 'red',
 'body and its parts': 'darkorange',
 'perception and emotion' : 'blue',
 'dietetic term': 'green',
 'quality': 'purple'}
terms_by_col_dict = {}
for key in terms_by_cat_dict.keys():
    #print(key)
    terms_by_col_dict[key] = cat_colors_dict[terms_by_cat_dict[key]]

for word, ax in zip(key_words, axs):
    xcol = pmi_svd_cos_pain_df[word + " cos.sim."]
    ycol = pmi_svd_cos_pain_df[word + " word"]
    actual_colors = [terms_by_col_dict[word] for word in ycol]
    sns.barplot(x=xcol, y=ycol, palette=actual_colors, ax=ax)
    ax.set(ylabel="", xlabel="Terms with highest \ncosine similarity with " + word)
    ax.set_xticks([0, 0.5, 1])
    ax.set_xlim(0, 1)
plt.subplots_adjust(hspace=0.08) # top=1, bottom=0, left=0, right=1, hspace=0.08, wspace=1.2)

markers = [plt.Line2D([0,0],[0,0],color=color, marker="s", linestyle="") for color in cat_colors_dict.values()]
plt.legend(markers, cat_colors_dict.keys(), numpoints=1,  title="Term categories", bbox_to_anchor=(1, 1), loc='upper left')

#plt.title("Terms with highest cosine similarity with the pain words ($PPMI^3$ based vectors)", loc="right")

# %%
sddk.write_file("public_data/PIA/pmmi3_svd.png", fig, conf)
# Out:
# A file with the same name ("pmmi3_svd.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/public_data/PIA/pmmi3_svd.png"

# %%
# set_with_dataframe(PIA_overview.add_worksheet("pmi_svd_cos_pain", 1, 1), pmi_svd_cos_pain_df)

# %%
def translate(term):
    try: return morpheus_by_lemma[term][0]["s"]
    except: return ""
terms_by_cat_df = get_as_dataframe(PIA_overview.worksheet("terms_by_cat"))
terms_by_cat_df["translation"] = terms_by_cat_df["term"].apply(translate)
terms_by_cat_df
# Out:
#            term       term_category     translation
# 0      πρότερος        general term           prae.
# 1        ψυχρός             quality     cold, chill
# 2       λαμβάνω        general term         to take
# 3        κεφαλή  body and its parts        the head
# 4       ἰσχυρός             quality  strong, mighty
# ..          ...                 ...             ...
# 107  ἐγγίγνομαι        general term      to be born
# 108     ἔρχομαι        general term         to come
# 109       παχύς             quality    thick, stout
# 110      σκέλος  body and its parts         the leg
# 111        ἄσις  body and its parts      slime, mud
#
# [112 rows x 3 columns]

# %%
set_with_dataframe(PIA_overview.add_worksheet("terms_tmp", 1, 1), terms_by_cat_df)

# %% [markdown]
# # PMI SVD cos plotting distances

# %%
pmi_svd_cos = pmi_svd_cos.round(5)
pmi_svd_cos
# Out:
#               εἰμί  γίγνομαι    οὗτος    πολύς      ἔχω    ἄλλος     σῶμα  \
# εἰμί       1.00000   0.96726  0.96323  0.96387  0.95266  0.90483  0.86701
# γίγνομαι   0.96726   1.00000  0.93421  0.95236  0.93512  0.88246  0.86900
# οὗτος      0.96323   0.93421  1.00000  0.94357  0.92155  0.89425  0.83148
# πολύς      0.96387   0.95236  0.94357  1.00000  0.92509  0.89451  0.85241
# ἔχω        0.95266   0.93512  0.92155  0.92509  1.00000  0.88191  0.85510
# ...            ...       ...      ...      ...      ...      ...      ...
# εὐεξίη     0.20656   0.19711  0.22778  0.21485  0.22091  0.25048  0.25621
# διηγέομαι  0.21749   0.21556  0.20751  0.22351  0.23528  0.23024  0.21600
# διαῤῥοίῃ   0.18145   0.20951  0.17711  0.17814  0.20347  0.20844  0.18936
# διαχωρέῃ   0.20579   0.21173  0.20370  0.21593  0.21882  0.22117  0.19043
# βῆχας      0.20697   0.22064  0.22128  0.22474  0.21083  0.19642  0.23405
#
#              ποιέω      χρή    αὐτός  ...    κωφός    κλίνω  καταπαύω  \
# εἰμί       0.86791  0.82824  0.86887  ...  0.19482  0.24637   0.22471
# γίγνομαι   0.83281  0.79002  0.85249  ...  0.19772  0.24233   0.24845
# οὗτος      0.86003  0.81244  0.84749  ...  0.19421  0.22479   0.22779
# πολύς      0.84097  0.79632  0.85656  ...  0.17818  0.23265   0.25681
# ἔχω        0.83740  0.83080  0.85621  ...  0.17392  0.25306   0.24186
# ...            ...      ...      ...  ...      ...      ...       ...
# εὐεξίη     0.23690  0.22514  0.20629  ...  0.26848  0.27165   0.24881
# διηγέομαι  0.21705  0.23783  0.20556  ...  0.37343  0.19041   0.19226
# διαῤῥοίῃ   0.19730  0.18951  0.18303  ...  0.18107  0.21212   0.11777
# διαχωρέῃ   0.21039  0.22279  0.21960  ...  0.11198  0.18526   0.15418
# βῆχας      0.21827  0.19086  0.22463  ...  0.24870  0.19647   0.26540
#
# βῆχας      0.78173  0.80914  0.77537  ...  0.75130  0.80353   0.73460
#
#            καταπίπτω  θόρυβος   εὐεξίη  διηγέομαι  διαῤῥοίῃ  διαχωρέῃ    βῆχας
# εἰμί         0.76961  0.80402  0.79344    0.78251   0.81855   0.79421  0.79303
# γίγνομαι     0.78638  0.78002  0.80289    0.78444   0.79049   0.78827  0.77936
# οὗτος        0.76917  0.81951  0.77222    0.79249   0.82289   0.79630  0.77872
# πολύς        0.77207  0.80101  0.78515    0.77649   0.82186   0.78407  0.77526
# ἔχω          0.74735  0.81444  0.77909    0.76472   0.79653   0.78118  0.78917
# ...              ...      ...      ...        ...       ...       ...      ...
# εὐεξίη       0.75599  0.94213  0.00000    0.74453   0.71586   0.70659  0.70889
# διηγέομαι    0.74086  0.89611  0.74453    0.00000   0.69346   0.82464  0.75075
# διαῤῥοίῃ     0.72695  0.90489  0.71586    0.69346   0.00000   0.94457  0.80354
# διαχωρέῃ     0.88105  0.97385  0.70659    0.82464   0.94457   0.00000  0.76232
# βῆχας        0.88843  0.95149  0.70889    0.75075   0.80354   0.76232  0.00000
#
# [2032 rows x 2032 columns]

# %%
# tSNE to project all words into a 2-dimensional space
data = pmi_svd_cos_dist

tsne = TSNE(n_components=2, random_state=42, perplexity=18, metric='precomputed', n_iter=5000) # dissimilarity="precomputed",

pos = tsne.fit_transform(data) # project all points into space
xs, ys = pos[:, 0], pos[:, 1]

# extract minimal and maximal values
minmax = [pos[:, 0].min(), pos[:, 0].max(), pos[:, 1].min(), pos[:, 1].max()]

# normalize on scale from 0 to 1
xs = (xs - minmax[0]) / (minmax[1] - minmax[0])
ys = (ys - minmax[2]) / (minmax[3] - minmax[2])

# %%
pain_xs, pain_ys = [], []
for x, y, word in zip(xs, ys, data.index):
    if word in key_words:
        pain_xs.append(x)
        pain_ys.append(y)
        
border = 0.03
xlim = np.min(pain_xs) - border, np.max(pain_xs) + border
ylim = np.min(pain_ys) - border, np.max(pain_ys) + border

# %%
# choose words to plot:
# tfidf words
tfidf_unique_words = ['ἄνθρωπος', 'σιτίον', 'πυρετός', 'ὀξύς', 'σῖτος', 'ὀδύν*', 'στῆθος', 'ἐσθίω', 'πόνο*', 'πλευροῦ', 'εἰμί', 'κεφαλή', 'ἐξέρχομαι', 'λαμβάνω', 'γαστήρ', 'σῶμα', 'μήτρα', 'ἀειδής', 'παρέχω', 'συμβαίνω', 'ἐπίνοσον', 'παύω', 'τράχηλος', 'ἡμέρα', 'γίγνομαι', 'οὗτος', 'χρόνος', 'ἔχω', 'βήξ', 'αἷμα', 'μεμιγμένα', 'πᾶς', 'ἴσχω', 'χολή', 'ὀσφῦς', 'ὀλίγος', 'σάρξ', 'ἰξύς', 'πολύς', 'προσήκω', 'ἄλγ*', 'ἰσχυρός', 'αὐτός', 'οὐδείς', 'ῥῖγος', 'κοιλία', 'νειαίρην', 'ἄλλος', 'κενεών']

words_to_plot = list(set(ppmi3_unique_words + ppmi3_unique_words + tfidf_unique_words))
len(words_to_plot)
# Out:
# 63

# %%
fig, [ax1, ax2] = plt.subplots(2,1, figsize=(8, 16), tight_layout=True)

# SUBPLOT "(A)"
for x, y, word in zip(xs, ys, data.index):
    if word not in key_words:
        if word in words_to_plot:
            ax1.scatter(x, y, s=12, marker="x", color=terms_by_col_dict[word], zorder=2)# c=np.array([terms_by_col_dict[word]]))
            #ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color=terms_by_col_dict[word], zorder=1)
        else:
            ax1.scatter(x, y, s=10, color="lightgrey", zorder=1)# c=np.array([terms_by_col_dict[word]]))
    if word in key_words:
        ax1.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
        ax1.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color=terms_by_col_dict[word], zorder=3)
    
# RECTANGLE
rect = patches.Rectangle((xlim[0],ylim[0]),xlim[1] - xlim[0], ylim[1] - ylim[0],linewidth=1,edgecolor='r',facecolor='none')
ax1.add_patch(rect)

ax1.axes.get_xaxis().set_visible(False)
ax1.axes.get_yaxis().set_visible(False)
ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 1.02)

ax1.set_title("(A)", loc="left")

# SUBPLOT "(B)"
for x, y, word in zip(xs, ys, data.index):
    if word in words_to_plot:
        if word not in key_words:
            if (xlim[1] - 0.01 > x > xlim[0] + 0.01) and (ylim[1] - 0.01 > y > ylim[0] + 0.01):            
                ax2.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
                ax2.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color=terms_by_col_dict[word], zorder=1)
    if word in key_words:
        ax2.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
        ax2.text(x, y-0.003, word, horizontalalignment='center', fontsize=16, color=terms_by_col_dict[word], zorder=2)
    
ax2.axes.get_xaxis().set_visible(False)
ax2.axes.get_yaxis().set_visible(False)
ax2.set_xlim(xlim)
ax2.set_ylim(ylim)

ax2.set_title("(B)", loc="left")

markers = [plt.Line2D([0,0],[0,0],color=color, marker="x", linestyle="") for color in cat_colors_dict.values()]
markers[0] = plt.Line2D([0,0],[0,0],color="gray", marker="o", linestyle="")
plt.legend(markers, cat_colors_dict.keys(), numpoints=1,  title="Term categories", bbox_to_anchor=(1, 1), loc='upper right', labelcolor='linecolor')

fig.suptitle("PPMI$^3_{SVD}$ embeddings - tSNE projection", fontsize=16)
# Out:
# Text(0.5, 0.98, 'PPMI$^3_{SVD}$ embeddings - tSNE projection')

# %%
sddk.write_file("public_data/PIA/pmmi3_svd_embdeddings1.png", fig, conf)
# Out:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/public_data/PIA/pmmi3_svd_embdeddings1.png"

# %%
rectangle_words = ['πόνο*', 'ἄλγ*', 'λύπ*']
redge = 0.08 # rectangle edge

# %%
rectangle_words_xy
# Out:
# {'πόνο*': [0.50479877, 0.442536],
#  'ἄλγ*': [0.54020286, 0.38290718],
#  'λύπ*': [0.7144038, 0.09840513]}

# %%
xy
# Out:
# [0.7144038, 0.09840513]

# %%
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2,2, figsize=(12, 12), tight_layout=True)

# SUBPLOT "(A)"
rectangle_words_xy = {}
for x, y, word in zip(xs, ys, data.index):
    if word not in key_words:
        if word in words_to_plot:
            ax1.scatter(x, y, s=12, marker="x", color=terms_by_col_dict[word], zorder=2)# c=np.array([terms_by_col_dict[word]]))
            #ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color=terms_by_col_dict[word], zorder=1)
        else:
            ax1.scatter(x, y, s=10, color="lightgrey", zorder=1)# c=np.array([terms_by_col_dict[word]]))
    # PAIN WORDS
    if word in key_words:
        ax1.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
        ax1.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color=terms_by_col_dict[word], zorder=3)
    # RECTANGLES
    if word in rectangle_words:
        rect = patches.Rectangle((x - redge/2,y - redge/2), redge, redge, linewidth=1,edgecolor='r',facecolor='none')
        ax1.add_patch(rect)
        rectangle_words_xy[word] = [x,y]

ax1.axes.get_xaxis().set_visible(False)
ax1.axes.get_yaxis().set_visible(False)
ax1.set_xlim(-0.02, 1.02)
ax1.set_ylim(-0.02, 1.02)

ax1.set_title("(A)", y=1, pad=-14)

markers = [plt.Line2D([0,0],[0,0],color=color, marker="x", linestyle="") for color in cat_colors_dict.values()]
markers[0] = plt.Line2D([0,0],[0,0],color="gray", marker="o", linestyle="")
ax1.legend(markers, cat_colors_dict.keys(), numpoints=1,  title="Term categories", bbox_to_anchor=(0, 1), loc='upper left', labelcolor='linecolor')

# RECTANGLES
titles = ["(B)", "(C)", "(D)"]
for ax, rec_word, title in zip([ax2, ax3, ax4], rectangle_words, titles):
    xy = rectangle_words_xy[rec_word]
    for x, y, word in zip(xs, ys, data.index):
        if (xy[0] + redge/2 > x > xy[0] - redge/2) and (xy[1] + redge/2 > y > xy[1] - redge/2):
            if word in key_words:
                ax.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
                ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=16, color=terms_by_col_dict[word], zorder=2)
            else: 
                if word in words_to_plot:
                    ax.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
                    ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color=terms_by_col_dict[word], zorder=1)
                else:
                    ax.scatter(x, y, s=10, color="white", zorder=1)# c=np.array([terms_by_col_dict[word]]))
                    ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color="gray", zorder=1)

    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_xlim(xy[0] - redge/1.8, xy[0] + redge/1.8)
    ax.set_ylim(xy[1] - redge/1.8, xy[1] + redge/1.8)
    ax.set_title(title, y=1, pad=-14)

#fig.suptitle("PPMI$^3_{SVD}$ embeddings - tSNE projection", fontsize=16)

# %%
sddk.write_file("public_data/PIA/pmmi3_svd_embdeddings4.png", fig, conf)
# Out:
# A file with the same name ("pmmi3_svd_embdeddings4.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/public_data/PIA/pmmi3_svd_embdeddings4.png"

# %%
rectangle_words_xy
# Out:
# {'πόνο*': [0.50479877, 0.442536],
#  'ἄλγ*': [0.54020286, 0.38290718],
#  'λύπ*': [0.7144038, 0.09840513]}

# %%
redge = redge * 1.5

# %%
fig, ax = plt.subplots(figsize=(6, 6), tight_layout=True)

xy = rectangle_words_xy["λύπ*"]
for x, y, word in zip(xs, ys, data.index):
    if (xy[0] + redge/2 > x > xy[0] - redge/2) and (xy[1] + redge/2 > y > xy[1] - redge/2):
        if word in key_words:
            ax.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
            ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=16, color=terms_by_col_dict[word], zorder=2)
        else: 
            if word in words_to_plot:
                ax.scatter(x, y, color="white")# c=np.array([terms_by_col_dict[word]]))
                ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color=terms_by_col_dict[word], zorder=1)
            else:
                ax.scatter(x, y, s=10, color="white", zorder=1)# c=np.array([terms_by_col_dict[word]]))
                ax.text(x, y-0.003, word, horizontalalignment='center', fontsize=10, color="gray", zorder=1)

ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.set_xlim(xy[0] - redge/1.8, xy[0] + redge/1.8)
ax.set_ylim(xy[1] - redge/1.8, xy[1] + redge/1.8)
ax.set_title(title, y=1, pad=-14)
# Out:
# Text(0.5, 1, '(D)')

# %%
for x, y, word in zip(xs, ys, data.index):
    if word in terms_by_cat_dict.keys():
        ax.scatter(x, y, c=np.array([color]))
        ax.text(x, y + 0.01, word, horizontalalignment='center', fontsize=10)


ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.set_xlim(- 0.1, 1.1)
title = "Corpus hippocraticum: Document distances based on vocabulary\n(work categories by Jouanna 1999)"
ax.set_title(title)


markers = [plt.Line2D([0,0],[0,0],color=color, marker='o', linestyle='') for color in color_values]
plt.legend(markers, color_keys, numpoints=1,  title="Work categories", fontsize=10, bbox_to_anchor=(1,1), loc="upper left")

# %%
terms_by_cat_dict = dict(zip(terms_by_cat_df["term"], terms_by_cat_df["term_category"]))
terms_by_cat_dict.keys()
# Out:
# {'πρότερος': 'temporal quality',
#  'ψυχρός': 'quality',
#  'λαμβάνω': 'general term',
#  'κεφαλή': 'bodily part or constituent',
#  'ἰσχυρός': 'quality',
#  'ἄνθρωπος': 'bodily part or constituent',
#  'χολή': 'bodily part or constituent',
#  'ὁπόσος': 'quality',
#  'ἄλγ*': 'pain-word',
#  'τρίτος': 'temporal quality',
#  'πᾶς': 'general term',
#  'πλείων': 'general term',
#  'σάρξ': 'bodily part or constituent',
#  'συμβαίνω': 'general term',
#  'θερμός': 'quality',
#  'μαλλός': 'general term',
#  'ἡμέρα': 'temporal quality',
#  'πόνο*': 'pain-word',
#  'ὀδύν*': 'pain-word',
#  'κοιλία': 'bodily part or constituent',
#  'εἶμι': 'general term',
#  'ποιέω': 'general term',
#  'γίγνομαι': 'general term',
#  'ἔχω': 'general term',
#  'καθίημι': 'general term',
#  'δοκέω': 'general term',
#  'δίδωμι': 'general term',
#  'ὀξύς': 'quality',
#  'πολύς': 'general term',
#  'μήτρα': 'bodily part or constituent',
#  'ἰξύς': 'bodily part or constituent',
#  'κενεών': 'bodily part or constituent',
#  'χρόνος': 'temporal quality',
#  'σιτίον': 'pathological state',
#  'ἴσχω': 'general term',
#  'ἐσθίω': 'dietetic term',
#  'νόσος': 'pathological state',
#  'σῶμα': 'bodily part or constituent',
#  'ὀσφύς': 'bodily part or constituent',
#  'ὀλίγος': 'quality',
#  'παύω': 'general term',
#  'γαστήρ': 'bodily part or constituent',
#  'αἷμα': 'bodily part or constituent',
#  'πυρετός': 'pathological state',
#  'ὀφθαλμός': 'bodily part or constituent',
#  'οὗτος': 'general term',
#  'ἄλλος': 'general term',
#  'αὐτός': 'general term',
#  'εἰμί': 'general term',
#  'λύπ*': 'pain-word',
#  'ὀσφῦς': 'bodily part or constituent',
#  'παρέχω': 'general term',
#  'οὐδείς': 'general term',
#  'προσήκω': 'general term',
#  'πλευροῦ': 'quality',
#  'τράχηλος': 'bodily part or constituent',
#  'ῥῖγος': 'quality',
#  'ἐξέρχομαι': 'general term',
#  'βήξ': 'pathological state',
#  'σῖτος': 'dietetic term',
#  'στῆθος': 'bodily part or constituent',
#  'μεμιγμένα': 'quality',
#  'ἀειδής': 'quality',
#  'νειαίρην': 'bodily part or constituent',
#  'ἐπίνοσον': 'pathological state',
#  'ἀποκρίνω': 'general term',
#  'Κοίλη': 'bodily part or constituent',
#  'βληχρός': 'quality',
#  'ἐπάγω': 'general term',
#  'σπλάγχνον': 'bodily part or constituent',
#  'οἷος': 'general term',
#  'οὐρέει': 'bodily part or constituent',
#  'πότος': 'dietetic term',
#  'ὁποῖος': 'general term',
#  'ἐπιλαμβάνω': 'general term',
#  'μέγας': 'quality',
#  'σκληρός': 'quality',
#  'χροιά': 'bodily part or constituent',
#  'ὑγιαίνω': 'dietetic term',
#  'ὁράω': 'general term',
#  'ὅρος': 'general term',
#  'γονή': 'bodily part or constituent',
#  'λεπτός': 'quality',
#  'πρόσωπον': 'bodily part or constituent',
#  'ψαύω': 'general term',
#  'φανερός': 'quality',
#  'ἐρωτάω': 'general term',
#  'κρύπτω': 'general term',
#  'ἰσχίον': 'bodily part or constituent',
#  'φοβερός': 'quality',
#  'αἰσθάνομαι': 'general term',
#  'νῶτον': 'bodily part or constituent',
#  'ὠχρός': 'pathological state',
#  'σύντονος': 'quality',
#  'ἡδονή': 'quality',
#  'οἰδέουσι': 'general term',
#  'πλευρόν': 'bodily part or constituent',
#  'ὀξείη': 'general term'}

# %%
terms_by_col_dict["γίγνομαι"]
# Out:
# 'gray'

# %% [markdown]
# # Backup: Previous experiments with LSA

# %%
svd = TruncatedSVD(n_components=250)
lsa = svd.fit_transform(tfidf)
lsa_doc = pd.DataFrame(lsa) #, columns=vocabulary)
lsa_doc
# Out:
#             0         1         2         3         4         5         6    \
# 0      0.291092  0.120812 -0.011414 -0.045221  0.087048 -0.015248  0.134973
# 1      0.113945 -0.048341  0.013215 -0.068549  0.199092  0.277817  0.038364
# 2      0.278826  0.343216 -0.054982 -0.059967 -0.113581  0.003020  0.013958
# 3      0.178850 -0.017742  0.019273 -0.042593  0.297982 -0.070750  0.074128
# 4      0.066580 -0.000201 -0.002682  0.012326  0.013823 -0.011123  0.012705
# ...         ...       ...       ...       ...       ...       ...       ...
# 24451  0.075155 -0.018564 -0.005475  0.073267  0.005832 -0.018919  0.031640
# 24452  0.296445  0.058825 -0.050300  0.135022  0.033343  0.169435  0.042056
# 24453  0.065155  0.040187  0.399040  0.056255 -0.012848 -0.014455  0.004877
# 24454  0.158804  0.026910 -0.011339 -0.081714 -0.097286 -0.011491 -0.005095
# 24455  0.028457  0.004306 -0.003069  0.009292  0.005569 -0.000576  0.006736
#
#             7         8         9    ...       240       241       242  \
# 0      0.037312  0.040419 -0.008096  ... -0.023577  0.023873  0.017753
# 1     -0.080837 -0.007310 -0.050582  ...  0.005202  0.005137  0.004956
# 2      0.001845  0.020055 -0.038230  ... -0.006006 -0.028921 -0.005711
# 3     -0.163608 -0.043452 -0.087134  ... -0.053331 -0.026377 -0.021582
# 4      0.024484  0.029276 -0.004064  ... -0.000818  0.008670 -0.014765
# ...         ...       ...       ...  ...       ...       ...       ...
# 24451 -0.021884  0.068928 -0.067545  ...  0.002607 -0.001323  0.003396
# 24452  0.001736  0.115289 -0.071581  ... -0.002363  0.007474  0.010698
# 24453 -0.012601  0.004090 -0.011182  ... -0.016274  0.000194 -0.001512
# 24454 -0.019178  0.002196 -0.016735  ... -0.005564  0.018009  0.014392
# 24455  0.003704  0.017221 -0.000771  ...  0.009538  0.078025  0.007266
#
#             243       244       245       246       247       248       249
# 0     -0.026195  0.012706  0.029686 -0.015625 -0.034971 -0.007640 -0.007286
# 1      0.000223  0.006238 -0.005648 -0.003812 -0.004576  0.005733 -0.003043
# 2      0.055508  0.012969 -0.002231 -0.004746 -0.062788  0.018479 -0.036495
# 3     -0.020280 -0.024655 -0.033270  0.029185  0.019736 -0.016080  0.044814
# 4     -0.025303 -0.008954  0.000089  0.012837 -0.018779  0.017352 -0.015500
# ἀποπέτομαι -0.001956  0.000276 -0.001185  0.000101  0.001000 -0.001763
# ἀναΐσσει    0.002093  0.000561 -0.000915  0.002104 -0.000686 -0.000118
# ἀλφίτοισι   0.000753 -0.000192  0.000098  0.000079  0.002321 -0.000988
# ἀλέα       -0.004470  0.001720 -0.000214 -0.001729  0.003497 -0.004029
#
#                  248       249
# εἰμί       -0.002744  0.000613
# γίγνομαι   -0.001804  0.000854
# οὗτος      -0.004133  0.001817
# πολύς       0.005255 -0.001397
# ἔχω         0.003596  0.002983
# ...              ...       ...
# ἀποστέλλω  -0.000358  0.000262
# ἀποπέτομαι -0.000187 -0.003585
# ἀναΐσσει   -0.003367  0.000138
# ἀλφίτοισι  -0.002716  0.004547
# ἀλέα        0.001528 -0.002014
#
# [2000 rows x 250 columns]

# %%
lsa_word_cos = pd.DataFrame(cosine_similarity(lsa_word.to_numpy()).round(5), columns=vocabulary, index=vocabulary)
lsa_word_cos
# Out:
#                εἰμί  γίγνομαι    οὗτος    πολύς      ἔχω    ἄλλος     σῶμα  \
# εἰμί        1.00000  -0.00104 -0.00017 -0.00001 -0.00038 -0.00007 -0.00040
# γίγνομαι   -0.00104   1.00000  0.00009 -0.00037 -0.00082 -0.00029  0.00015
# οὗτος      -0.00017   0.00009  1.00000 -0.00015  0.00010 -0.00011 -0.00036
# πολύς      -0.00001  -0.00037 -0.00015  1.00000 -0.00006 -0.00025  0.00008
# ἔχω        -0.00038  -0.00082  0.00010 -0.00006  1.00000 -0.00016 -0.00014
# ...             ...       ...      ...      ...      ...      ...      ...
# ἀποστέλλω  -0.02031  -0.00493 -0.02526 -0.00753 -0.01552 -0.01677  0.10073
# ἀποπέτομαι -0.00872   0.00815 -0.01083  0.01969 -0.00505 -0.01221  0.05677
# ἀναΐσσει   -0.00344   0.01265  0.01191  0.01149  0.02694  0.01458  0.01206
# ἀλφίτοισι  -0.00716  -0.00159  0.00364 -0.00295 -0.00575 -0.00255 -0.00138
# ἀλέα       -0.00451   0.01221 -0.02468  0.05481 -0.00837  0.03819  0.07529
#
#               ποιέω      χρή    αὐτός  ...  ἀσθενείη  ἀπύρετος  ἀπόπατος  \
# εἰμί       -0.00047 -0.00001 -0.00024  ...  -0.01677   0.12176  -0.00279
# γίγνομαι   -0.00067 -0.00011 -0.00033  ...   0.01665  -0.00345   0.06058
# οὗτος       0.00030  0.00013 -0.00041  ...   0.05083  -0.01183   0.05480
# πολύς      -0.00024  0.00030 -0.00023  ...  -0.02689   0.00808  -0.01440
# ἔχω        -0.00026  0.00014 -0.00011  ...   0.02605  -0.02282  -0.01585
# ...             ...      ...      ...  ...       ...       ...       ...
# ἀποστέλλω   0.10660 -0.00582 -0.03260  ...   0.04649  -0.05125  -0.03915
# ἀποπέτομαι -0.01239 -0.00451  0.02542  ...   0.02873  -0.06885   0.03287
# ἀναΐσσει   -0.01116 -0.01048  0.02127  ...   0.01167  -0.09959  -0.07131
# ἀλφίτοισι  -0.01112 -0.00518 -0.00910  ...  -0.07956   0.05779  -0.04862
# ἀλέα        0.10866 -0.02287  0.00372  ...   0.03271   0.00526  -0.02515
#
#              ἀπωθέω  ἀποτελευτάω  ἀποστέλλω  ἀποπέτομαι  ἀναΐσσει  ἀλφίτοισι  \
# εἰμί       -0.01038     -0.00766   -0.02031    -0.00872  -0.00344   -0.00716
# γίγνομαι   -0.00745     -0.00191   -0.00493     0.00815   0.01265   -0.00159
# οὗτος      -0.00279     -0.00102   -0.02526    -0.01083   0.01191    0.00364
# πολύς      -0.00393     -0.02168   -0.00753     0.01969   0.01149   -0.00295
# ἔχω        -0.00636     -0.01980   -0.01552    -0.00505   0.02694   -0.00575
# ...             ...          ...        ...         ...       ...        ...
# ἀποστέλλω  -0.01910     -0.01652    1.00000     0.03234   0.02619   -0.07021
# ἀποπέτομαι -0.03588      0.17936    0.03234     1.00000  -0.02274   -0.04724
# ἀναΐσσει   -0.00159      0.07013    0.02619    -0.02274   1.00000    0.00697
# ἀλφίτοισι  -0.03991     -0.00792   -0.07021    -0.04724   0.00697    1.00000
# ἀλέα       -0.00448     -0.05292   -0.02607    -0.03297  -0.05355    0.03752
#
#                ἀλέα
# εἰμί       -0.00451
# γίγνομαι    0.01221
# οὗτος      -0.02468
# πολύς       0.05481
# ἔχω        -0.00837
# ...             ...
# ἀποστέλλω  -0.02607
# ἀποπέτομαι -0.03297
# ἀναΐσσει   -0.05355
# ἀλφίτοισι   0.03752
# ἀλέα        1.00000
#
# [2000 rows x 2000 columns]

# %%
lsa_word_cos.sort_values("αἰτία", ascending=False)["αἰτία"][1:11]
# Out:
# ἐπιφέρω        0.39020
# ἄδηλος         0.39018
# αἴτιος         0.38436
# ἀπόκρισις      0.38083
# ὅδε            0.37467
# πάθος          0.36896
# θεός           0.35816
# προειρημένα    0.34045
# ἔργον          0.32858
# καλός          0.32827
# Name: αἰτία, dtype: float64

# %%
lsa_word_cos.sort_values("ὀδύν*", ascending=False)["ὀδύν*"][1:11]
# Out:
# ἀπαλλάσσηται    0.44013
# χλιαίνειν       0.43666
# πλευρίτιδι      0.42847
# ὀξείη           0.37870
# βρέγμα          0.33909
# πλευροῦ         0.33297
# νάρκη           0.30313
# χλιάσματα       0.26793
# φοιτάω          0.25847
# ἄχθομαι         0.25395
# Name: ὀδύν*, dtype: float64

# %%
lsa_word_cos.sort_values("πόνο*", ascending=False)["πόνο*"][1:11]
# Out:
# δύσπνοια       0.30235
# ἀποπέτομαι     0.26514
# γυμνάζω        0.21987
# περισσῇσιν     0.21487
# κουφίζω        0.21327
# ὑποχονδρίῳ     0.20942
# εἴλω           0.20890
# ἀποτελευτάω    0.20226
# σύμμετρος      0.19750
# ἀφωνίαι        0.19118
# Name: πόνο*, dtype: float64

# %%
def get_most_similar(model_df, target_term, number):
    all_similar = []
    for term in model_df.columns:
        similarity = (term, cosine_similarity([model_df[target_term],  model_df[term]])[0][1])
        all_similar.append(similarity)
    return sorted(all_similar, key=lambda number: number[1], reverse=True)[1:number]

# %%
key_words = ['λύπ*', 'ἄλγ*', 'ὀδύν*', 'πόνο*']

# %%
for word in key_words:
    if word in lsa_word_cos.index:
        print(word)
# Out:
# λύπ*
# ἄλγ*
# ὀδύν*
# πόνο*
