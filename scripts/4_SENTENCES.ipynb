# %%
### PREREQUISTIES
### (many used only in one notebook...)

import os
import pandas as pd
import numpy as np
import logging ### to monitor the code
from bs4 import BeautifulSoup
import pickle
import math
import random
import sys
import csv
import unicodedata
import requests
import re
import json

import nltk
from nltk.collocations import *

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

import xml.etree.cElementTree as ET
from urllib.request import urlopen

import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
#from google.colab import auth
#from oauth2client.client import GoogleCredentials
from google.oauth2 import service_account # based on google-auth library
import sddk

# %%
"https://sciencedata.dk/public/8fe7d59de1eafe5f8eaebc0044534606"
# Out:
# 'https://sciencedata.dk/public/8fe7d59de1eafe5f8eaebc0044534606'

# %%
publicfolder = "8fe7d59de1eafe5f8eaebc0044534606"
morpheus_by_lemma = json.loads(requests.get("https://sciencedata.dk/public/" + publicfolder + "/morpheus_by_lemma.json").content)

# %%
#!pip install anda
#from anda import gr ### the import takes substantial time, since it import a +600MB file containing ancient Greek dictionary

# %%
### not neccessary for reading the data, just for exporting them to sciencedata.dk
conf = sddk.configure()
# Out:
# sciencedata.dk username (format '123456@au.dk'): 648597@au.dk
# sciencedata.dk password: ········
# endpoint variable has been configured to: https://sciencedata.dk/files/

# %%
# to access gsheet, you need Google Service Account key json file
# I have mine located in my personal space on sciencedata.dk, so I read it from there:

# (1) read the file and parse its content
file_data = conf[0].get(conf[1] + "ServiceAccountsKey.json").json()
# (2) transform the content into crendentials object
credentials = service_account.Credentials.from_service_account_info(file_data)
# (3) specify your usage of the credentials
scoped_credentials = credentials.with_scopes(['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive'])
# (4) use the constrained credentials for authentication of gspread package
gc = gspread.Client(auth=scoped_credentials)
# (5) establish connection with spreadsheets specified by their url
PIA_data = gc.open_by_url("https://docs.google.com/spreadsheets/d/1KxOx7Be9fj3lDcEPgQhQ-Iqcn9p367-MMD6RMXe8rks/edit?usp=sharing")
PIA_overview = gc.open_by_url("https://docs.google.com/spreadsheets/d/1e94wyelg6dftQ4zxbq1xvwxWAI-BhcYXtclDW-YTnrw/edit?usp=sharing")

# %%
publicfolder = "31b393e2afe1ee96ce81869c7efe18cb"
c_hippocraticum = sddk.read_file("c_hippocraticum_enriched.json", "df", publicfolder)
# Out:
# reading file located in a public folder

# %%
c_hippocraticum.columns
# Out:
# Index(['filename', 'author', 'title', 'wordcount', 'author_id', 'doc_id',
#        'raw_date', 'date_avr', 'date_probs', 'date_manual', 'provenience',
#        'tlg_epithet', 'clean_string', 'n_sentences', 'lemmatized_sentences',
#        'lemmata', 'lemmata_wordcount', 'lemmata_repl',
#        'lemmatized_sentences_repl', 'λύπ*', 'ἄλγ*', 'ὀδύν*', 'πόνο*',
#        'terms_sum', 'λύπ*_TF', 'ἄλγ*_TF', 'ὀδύν*_TF', 'πόνο*_TF', 'TF_sum',
#        'work_cat_jouanna', 'work_cat_craik', 'work_cat_linka'],
#       dtype='object')

# %%
# the viper is out!!!
c_hippocraticum["lemmata_repl"].apply(lambda x: x.count("ἔχις")).sum()
# Out:
# 0

# %%
key_words = ['πόνο*', 'ὀδύν*', 'ἄλγ*', 'λύπ*']

# %%
def sentences_with_term(sentences, term, flatlist=False):
    sentences_with_term = [sen for sen in sentences if term in sen]
    if flatlist == True:
        flatlist = [word for sen in sentences_with_term for word in sen]
        return flatlist
    else: 
        return sentences_with_term

# %%
for word in key_words:
    c_hippocraticum[word + "_sents"] = c_hippocraticum["lemmatized_sentences_repl"].apply(lambda x: sentences_with_term(x, word, True))

# %%
for word in key_words:
    c_hippocraticum[word + "_sents"] = c_hippocraticum[word + "_sents"].apply(lambda sentences:  [word for word in sentences if word not in ["ἢν", "ὁκόταν"]])

# %%
all_sents = [sent for doc_sents in c_hippocraticum["lemmatized_sentences_repl"].tolist() for sent in doc_sents]
len(all_sents)
# Out:
# 24456

# %%
print(all_sents[:3])
# Out:
# [['ὁπόσος', 'ἐπιχειρέω', 'ἰητρικῆς', 'λέγω', 'γράφω', 'ὑπόθεσις', 'αὐτός', 'ὑποθέμενοι', 'λόγος', 'θερμός', 'ψυχρός', 'ὑγρός', 'ξηρός', 'ἄλλος', 'ἐθέλω', 'βραχύς', 'ἄγω', 'ἀρχή', 'αἰτία', 'ἄνθρωπος', 'νοῦσος', 'θάνατος', 'πᾶς', 'αὐτός', 'εἷς', 'ὑποθέμενοι', 'πολύς', 'λέγω', 'καταφανής', 'εἰμί', 'ἁμαρτάνω', 'ἄξιος', 'μέμφομαι', 'τέχνη', 'εἰμί', 'χράω', 'πᾶς', 'μέγας', 'τιμάω', 'ἀγαθός', 'χειροτέχνης', 'δημιουργός'], ['δημιουργός', 'φαῦλος', 'πολύς', 'διαφέροντες'], ['εἰμί', 'ἰατρικός', 'αὐτός', 'ἔσκεπτο', 'εὑρίσκω', 'μηδείς', 'εἰμί', 'πᾶς', 'ἄπειρος', 'ἀνεπιστήμων', 'εἰμί', 'τύχη', 'κάμνω', 'διοικεῖτο']]

# %%
wordlists = {}
for word in key_words:
    corpus_wordlist = []
    for wordlist in c_hippocraticum[word + "_sents"]:
        corpus_wordlist.extend(wordlist)
    wordlists[word] = corpus_wordlist

# %%
wordlists_freqs = {}
for word in key_words:
    word_counts = nltk.FreqDist(wordlists[word]).most_common(21)
    word_count = c_hippocraticum[word + "_sents"].apply(lambda x: len(x)).sum()
    word_freqs = [(tup[0], np.round(tup[1] / word_count, 5)) for tup in word_counts]
    wordlists_freqs[word + " word"] = [tup[0] for tup in word_counts]
wordlists_freqs_df = pd.DataFrame(wordlists_freqs)
wordlists_freqs_df
# Out:
#    πόνο* word ὀδύν* word ἄλγ* word λύπ* word
# 0       πόνο*      ὀδύν*      ἄλγ*      λύπ*
# 1    γίγνομαι        ἔχω      εἰμί      εἰμί
# 2       πολύς   γίγνομαι   πυρετός  γίγνομαι
# 3        εἰμί       εἰμί    κεφαλή  ἄνθρωπος
# 4        σῶμα    πυρετός  γίγνομαι      σῶμα
# 5         ἔχω      πολύς       ἔχω     αὐτός
# 6       οὗτος     κεφαλή     ὀδύν*     οὗτος
# 7       ἄλλος     γαστήρ    κοιλία     πολύς
# 8      κοιλία      οὗτος     οὗτος    κοιλία
# 9     πυρετός       ἴσχω    γαστήρ    οὐδείς
# 10        πᾶς     παρέχω     ὀσφῦς     ἡμέρα
# 11     χρόνος       ὀξύς     πολύς     ἄλλος
# 12     σιτίον     κοιλία      σῶμα       ἔχω
# 13      ἡμέρα       αἷμα       πᾶς    ὀλίγος
# 14    ἰσχυρός    λαμβάνω      ἴσχω    χρόνος
# 15      αὐτός     δίδωμι     αὐτός  συμβαίνω
# 16     παρέχω       ἄλγ*      αἷμα     πόνο*
# 17       σάρξ       ἰξύς     μήτρα     ἐσθίω
# 18   ἄνθρωπος     θερμός      χολή    ψυχρός
# 19       αἷμα    ἰσχυρός     πόνο*   πυρετός
# 20     κεφαλή      ἄλλος   λαμβάνω     ποιέω

# %%
unique_words = []
for col in wordlists_freqs_df.columns:
    unique_words.extend(wordlists_freqs_df[col].tolist())
unique_words = list(set(unique_words))

# %%
wordlists_freqs = {}
for word in key_words:
    word_counts = nltk.FreqDist(wordlists[word]).most_common(21)
    c_hippocraticum[word + "_sents"]
    word_count = c_hippocraticum[word + "_sents"].apply(lambda x: len(x)).sum()
    word_freqs = [(tup[0], np.round(tup[1] / word_count, 5)) for tup in word_counts]
    wordlists_freqs[word + " (n={0})".format(word_counts[0][1]) ] = word_freqs[1:]
wordlists_freqs_df = pd.DataFrame(wordlists_freqs)
wordlists_freqs_df
# Out:
#           πόνο* (n=657)        ὀδύν* (n=645)         ἄλγ* (n=315)  \
# 0   (γίγνομαι, 0.02052)       (ἔχω, 0.02284)      (εἰμί, 0.01698)
# 1       (πολύς, 0.0179)  (γίγνομαι, 0.02245)   (πυρετός, 0.01644)
# 2       (εἰμί, 0.01615)      (εἰμί, 0.01527)    (κεφαλή, 0.01644)
# 3       (σῶμα, 0.01514)   (πυρετός, 0.01411)  (γίγνομαι, 0.01644)
# 4        (ἔχω, 0.01092)     (πολύς, 0.01334)       (ἔχω, 0.01617)
# 5      (οὗτος, 0.01004)    (κεφαλή, 0.01142)      (ὀδύν*, 0.0124)
# 6       (ἄλλος, 0.0099)    (γαστήρ, 0.01026)    (κοιλία, 0.01105)
# 7     (κοιλία, 0.00844)     (οὗτος, 0.00885)     (οὗτος, 0.01024)
# 8    (πυρετός, 0.00844)      (ἴσχω, 0.00795)    (γαστήρ, 0.00943)
# 9        (πᾶς, 0.00742)    (παρέχω, 0.00693)     (ὀσφῦς, 0.00916)
# 10    (χρόνος, 0.00655)      (ὀξύς, 0.00654)     (πολύς, 0.00728)
# 11    (σιτίον, 0.00509)    (κοιλία, 0.00642)      (σῶμα, 0.00701)
# 12     (ἡμέρα, 0.00495)      (αἷμα, 0.00642)       (πᾶς, 0.00566)
# 13    (ἰσχυρός, 0.0048)    (λαμβάνω, 0.0059)      (ἴσχω, 0.00539)
# 14      (αὐτός, 0.0048)     (δίδωμι, 0.0059)     (αὐτός, 0.00539)
# 15     (παρέχω, 0.0048)      (ἄλγ*, 0.00565)      (αἷμα, 0.00512)
# 16       (σάρξ, 0.0048)      (ἰξύς, 0.00565)     (μήτρα, 0.00485)
# 17  (ἄνθρωπος, 0.00466)    (θερμός, 0.00539)      (χολή, 0.00458)
# 18      (αἷμα, 0.00466)   (ἰσχυρός, 0.00526)     (πόνο*, 0.00458)
# 19    (κεφαλή, 0.00466)     (ἄλλος, 0.00526)   (λαμβάνω, 0.00458)
#
#             λύπ* (n=58)
# 0       (εἰμί, 0.03714)
# 1   (γίγνομαι, 0.02122)
# 2   (ἄνθρωπος, 0.01592)
# 3       (σῶμα, 0.01592)
# 4      (αὐτός, 0.01592)
# 5      (οὗτος, 0.01459)
# 6      (πολύς, 0.01459)
# 7     (κοιλία, 0.00928)
# 8     (οὐδείς, 0.00796)
# 9      (ἡμέρα, 0.00796)
# 10     (ἄλλος, 0.00796)
# 11       (ἔχω, 0.00796)
# 12    (ὀλίγος, 0.00796)
# 13    (χρόνος, 0.00663)
# 14  (συμβαίνω, 0.00663)
# 15     (πόνο*, 0.00663)
# 16     (ἐσθίω, 0.00663)
# 17    (ψυχρός, 0.00531)
# 18   (πυρετός, 0.00531)
# 19     (ποιέω, 0.00531)

# %%
#set_with_dataframe(PIA_overview.add_worksheet("tfs-in-sentences", 1, 1), wordlists_freqs_df)

# %%
wordlists_freqs = {}
for word in key_words:
    word_counts = nltk.FreqDist(wordlists[word]).most_common(21)
    c_hippocraticum[word + "_sents"]
    word_count = c_hippocraticum[word + "_sents"].apply(lambda x: len(x)).sum()
    tfs = [np.round(tup[1] / word_count, 5) for tup in word_counts]
    tf_words = [tup[0] for tup in word_counts]
    wordlists_freqs[word + " words"] = tf_words[1:]
    wordlists_freqs[word + " TFs"] = tfs[1:]
wordlists_freqs_df = pd.DataFrame(wordlists_freqs)
wordlists_freqs_df
# Out:
#    πόνο* words  πόνο* TFs ὀδύν* words  ὀδύν* TFs ἄλγ* words  ἄλγ* TFs  \
# 0     γίγνομαι    0.02052         ἔχω    0.02284       εἰμί   0.01698
# 1        πολύς    0.01790    γίγνομαι    0.02245    πυρετός   0.01644
# 2         εἰμί    0.01615        εἰμί    0.01527     κεφαλή   0.01644
# 3         σῶμα    0.01514     πυρετός    0.01411   γίγνομαι   0.01644
# 4          ἔχω    0.01092       πολύς    0.01334        ἔχω   0.01617
# 5        οὗτος    0.01004      κεφαλή    0.01142      ὀδύν*   0.01240
# 6        ἄλλος    0.00990      γαστήρ    0.01026     κοιλία   0.01105
# 7       κοιλία    0.00844       οὗτος    0.00885      οὗτος   0.01024
# 8      πυρετός    0.00844        ἴσχω    0.00795     γαστήρ   0.00943
# 9          πᾶς    0.00742      παρέχω    0.00693      ὀσφῦς   0.00916
# 10      χρόνος    0.00655        ὀξύς    0.00654      πολύς   0.00728
# 11      σιτίον    0.00509      κοιλία    0.00642       σῶμα   0.00701
# 12       ἡμέρα    0.00495        αἷμα    0.00642        πᾶς   0.00566
# 13     ἰσχυρός    0.00480     λαμβάνω    0.00590       ἴσχω   0.00539
# 14       αὐτός    0.00480      δίδωμι    0.00590      αὐτός   0.00539
# 15      παρέχω    0.00480        ἄλγ*    0.00565       αἷμα   0.00512
# 16        σάρξ    0.00480        ἰξύς    0.00565      μήτρα   0.00485
# 17    ἄνθρωπος    0.00466      θερμός    0.00539       χολή   0.00458
# 18        αἷμα    0.00466     ἰσχυρός    0.00526      πόνο*   0.00458
# 19      κεφαλή    0.00466       ἄλλος    0.00526    λαμβάνω   0.00458
#
#    λύπ* words  λύπ* TFs
# 0        εἰμί   0.03714
# 1    γίγνομαι   0.02122
# 2    ἄνθρωπος   0.01592
# 3        σῶμα   0.01592
# 4       αὐτός   0.01592
# 5       οὗτος   0.01459
# 6       πολύς   0.01459
# 7      κοιλία   0.00928
# 8      οὐδείς   0.00796
# 9       ἡμέρα   0.00796
# 10      ἄλλος   0.00796
# 11        ἔχω   0.00796
# 12     ὀλίγος   0.00796
# 13     χρόνος   0.00663
# 14   συμβαίνω   0.00663
# 15      πόνο*   0.00663
# 16      ἐσθίω   0.00663
# 17     ψυχρός   0.00531
# 18    πυρετός   0.00531
# 19      ποιέω   0.00531

# %%
most_common = []
for word in key_words:
    wordlist = wordlists_freqs_df[word + " words"].tolist()
    most_common.extend(wordlist)
most_common_unique = list(set(most_common))
most_common_unique_df = pd.DataFrame(most_common_unique)

# %%
terms_by_cat_df = get_as_dataframe(PIA_overview.worksheet("terms_by_cat"))
terms_by_cat_dict = dict(zip(terms_by_cat_df["term"], terms_by_cat_df["term_category"]))
terms_by_cat_dict
# Out:
# {'πρότερος': 'temporal quality',
#  'ψυχρός': 'quality',
#  'λαμβάνω': 'general term',
#  'κεφαλή': 'bodily part or constituent',
#  'ἰσχυρός': 'quality',
#  'ἄνθρωπος': 'bodily part or constituent',
#  'χολή': 'bodily part or constituent',
#  'ὁπόσος': 'quality',
#  'ἄλγ*': 'pain-word',
#  'τρίτος': 'temporal quality',
#  'πᾶς': 'general term',
#  'πλείων': 'general term',
#  'σάρξ': 'bodily part or constituent',
#  'συμβαίνω': 'general term',
#  'θερμός': 'quality',
#  'μαλλός': 'general term',
#  'ἡμέρα': 'temporal quality',
#  'πόνο*': 'pain-word',
#  'ὀδύν*': 'pain-word',
#  'κοιλία': 'bodily part or constituent',
#  'εἶμι': 'general term',
#  'ποιέω': 'general term',
#  'γίγνομαι': 'general term',
#  'ἔχω': 'general term',
#  'καθίημι': 'general term',
#  'δοκέω': 'general term',
#  'δίδωμι': 'general term',
#  'ὀξύς': 'quality',
#  'πολύς': 'general term',
#  'μήτρα': 'bodily part or constituent',
#  'ἰξύς': 'bodily part or constituent',
#  'κενεών': 'bodily part or constituent',
#  'χρόνος': 'temporal quality',
#  'σιτίον': 'pathological state',
#  'ἴσχω': 'general term',
#  'ἐσθίω': 'dietetic term',
#  'νόσος': 'pathological state',
#  'σῶμα': 'bodily part or constituent',
#  'ὀσφύς': 'bodily part or constituent',
#  'ὀλίγος': 'quality',
#  'παύω': 'general term',
#  'γαστήρ': 'bodily part or constituent',
#  'αἷμα': 'bodily part or constituent',
#  'πυρετός': 'pathological state',
#  'ὀφθαλμός': 'bodily part or constituent',
#  'οὗτος': 'general term',
#  'ἄλλος': 'general term',
#  'αὐτός': 'general term',
#  'εἰμί': 'general term',
#  'λύπ*': 'pain-word',
#  'ὀσφῦς': 'bodily part or constituent',
#  'παρέχω': 'general term',
#  'οὐδείς': 'general term',
#  'προσήκω': 'general term',
#  'πλευροῦ': 'quality',
#  'τράχηλος': 'bodily part or constituent',
#  'ῥῖγος': 'quality',
#  'ἐξέρχομαι': 'general term',
#  'βήξ': 'pathological state',
#  'σῖτος': 'dietetic term',
#  'στῆθος': 'bodily part or constituent',
#  'μεμιγμένα': 'quality',
#  'ἀειδής': 'quality',
#  'νειαίρην': 'bodily part or constituent',
#  'ἐπίνοσον': 'pathological state',
#  'ἀποκρίνω': 'general term',
#  'Κοίλη': 'general term',
#  'βληχρός': 'general term',
#  'ἐπάγω': 'general term',
#  'σπλάγχνον': 'general term',
#  'οἷος': 'general term',
#  'οὐρέει': 'general term',
#  'πότος': 'general term',
#  'ὁποῖος': 'general term',
#  'ἐπιλαμβάνω': 'general term',
#  'μέγας': 'general term',
#  'σκληρός': 'general term',
#  'χροιά': 'general term',
#  'ὑγιαίνω': 'general term',
#  'ὁράω': 'general term',
#  'ὅρος': 'general term',
#  'γονή': 'general term',
#  'λεπτός': 'general term',
#  'πρόσωπον': 'general term',
#  'ψαύω': 'general term',
#  'φανερός': 'general term',
#  'ἐρωτάω': 'general term'}

# %%
[word for word in unique_words if word not in terms_by_cat_dict.keys()]
# Out:
# []

# %%
#words_for_coding = [word for word in unique_words if word not in terms_by_cat_dict.keys()]
#set_with_dataframe(PIA_overview.add_worksheet("words_for_coding_20201202", 1, 1), pd.DataFrame(words_for_coding))

# %%
# https://matplotlib.org/3.1.0/gallery/color/named_colors.html
import matplotlib.colors as mcolors
colors_list = list(mcolors.TABLEAU_COLORS.keys()) + list(mcolors.BASE_COLORS.keys())
# remove white
colors_list = [col for col in colors_list if col not in ["b", "w"]] 
print(colors_list)
# Out:
# ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan', 'g', 'r', 'c', 'm', 'y', 'k']

# %%
term_cats = list(set(terms_by_cat_dict.values()))
print(term_cats)
# Out:
# ['pain-word', 'pathological state', 'bodily part or constituent', 'temporal quality', 'general term', 'dietetic term', 'quality']

# %%
colors = ["darkred", "red", "orange", "black", "gray", "green","lightgray"]
cat_colors_dict = dict(zip(term_cats, colors))
cat_colors_dict
# Out:
# {'pain-word': 'darkred',
#  'pathological state': 'red',
#  'bodily part or constituent': 'orange',
#  'temporal quality': 'black',
#  'general term': 'gray',
#  'dietetic term': 'green',
#  'quality': 'lightgray'}

# %%
morpheus_by_lemma["σῖτος"]
# Out:
# [{'d': 29633, 'l': 'σῖτος', 's': 'corn, grain', 'a': None}]

# %%
cat_colors_dict["bodily part or constituent"] #terms_by_col_dict[key]]
# Out:
# 'orange'

# %%
cat_colors_dict[terms_by_cat_dict["γίγνομαι"]]
# Out:
# 'gray'

# %%
terms_by_col_dict = {}
for key in terms_by_cat_dict.keys():
    #print(key)
    terms_by_col_dict[key] = cat_colors_dict[terms_by_cat_dict[key]]

# %%
#plt.rcParams['figure.figsize'] = [12, 4]
fig, axs = plt.subplots(1, 4, figsize=[12,4], tight_layout=True)

for word, ax in zip(key_words, axs):
    xcol = wordlists_freqs_df[word + " TFs"]
    ycol = wordlists_freqs_df[word + " words"]
    actual_colors = [terms_by_col_dict[word] for word in ycol]
    sns.barplot(x=xcol, y=ycol, palette=actual_colors, ax=ax)
    ax.set(ylabel="", xlabel="TF of terms within\nsentences with " + word)

plt.subplots_adjust(hspace=0.08) # top=1, bottom=0, left=0, right=1, hspace=0.08, wspace=1.2)

#plt.title("Most frequent terms in sentences containing pain-words                       ", loc="right")

markers = [plt.Line2D([0,0],[0,0],color=color, marker="s", linestyle="") for color in colors]
plt.legend(markers, term_cats, numpoints=1,  title="Term categories", bbox_to_anchor=(1, 1), loc='upper left')

# %%
sddk.write_file("public_data/PIA/terms_in_sentences_20201213.png", fig, conf)
# Out:
# A file with the same name ("terms_in_sentences_20201213.png") already exists in this location.
# Press Enter to overwrite it or choose different path and filename:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/public_data/PIA/terms_in_sentences_20201213.png"

# %% [markdown]
# https://sciencedata.dk/public/31b393e2afe1ee96ce81869c7efe18cb/terms_in_sentences_20201207.png

# %% [markdown]
# # TFIDF

# %%
def term_idf(term):
    idf_raw =  len(all_sents) / len([sent for sent in all_sents if term in sent])
    idf_log = math.log(idf_raw)
    return idf_log
#authors_df["dik_sents_TFIDF"] = authors_df.apply(lambda x: get_tfidf(x["dik_sents_flat"], x["lemmatized_sentences"]), axis=1)

# %%
pain_words_sents = {}
for col in [col for col in c_hippocraticum.columns if "*_sents" in col]:
    pain_words_sents[col.partition("_")[0] + "_all_sents"] = {}
    list_of_lists = c_hippocraticum[col].tolist()
    words = [word for doc in list_of_lists for word in doc if word != col.partition("_")[0]]
    word_counts = nltk.FreqDist(words).most_common()
    FD = [(tup[0] , np.round(tup[1]  / len(words), 5)) for tup in word_counts]
    TFIDF = [(tup[0], np.round(tup[1] * term_idf(tup[0]), 5)) for tup in FD]
    TFIDF = sorted(TFIDF, key=lambda tup: tup[1], reverse=True)    
    pain_words_sents[col.partition("_")[0] + "_all_sents"] = {"words" : words, "word_counts" : word_counts, "FD" : FD, "TFIDF": TFIDF}

# %%
pain_words_sents.keys()
# Out:
# dict_keys(['λύπ*_all_sents', 'ἄλγ*_all_sents', 'ὀδύν*_all_sents', 'πόνο*_all_sents'])

# %%
pain_words_sents["λύπ*_all_sents"]["FD"]
# Out:
# [('εἰμί', 0.04023),
#  ('γίγνομαι', 0.02299),
#  ('ἄνθρωπος', 0.01724),
#  ('σῶμα', 0.01724),
#  ('αὐτός', 0.01724),
#  ('οὗτος', 0.0158),
#  ('πολύς', 0.0158),
#  ('κοιλία', 0.01006),
#  ('οὐδείς', 0.00862),
#  ('ἡμέρα', 0.00862),
#  ('ἄλλος', 0.00862),
#  ('ἔχω', 0.00862),
#  ('ὀλίγος', 0.00862),
#  ('χρόνος', 0.00718),
#  ('συμβαίνω', 0.00718),
#  ('πόνο*', 0.00718),
#  ('ἐσθίω', 0.00718),
#  ('ψυχρός', 0.00575),
#  ('πυρετός', 0.00575),
#  ('ποιέω', 0.00575),
#  ('πρῶτος', 0.00431),
#  ('πάρειμι', 0.00431),
#  ('τρίτος', 0.00431),
#  ('ἰσχυρός', 0.00431),
#  ('χρή', 0.00431),
#  ('τοιοῦτος', 0.00431),
#  ('κεφαλή', 0.00431),
#  ('λαμβάνω', 0.00431),
#  ('ὀστέον', 0.00431),
#  ('ψυχή', 0.00431),
#  ('λέγω', 0.00431),
#  ('προσήκω', 0.00431),
#  ('ἕτερος', 0.00431),
#  ('ἐξέρχομαι', 0.00431),
#  ('χολή', 0.00431),
#  ('πῦρ', 0.00431),
#  ('ἰκμάς', 0.00431),
#  ('τὶς', 0.00431),
#  ('ὑγιής', 0.00431),
#  ('πᾶς', 0.00431),
#  ('πίνω', 0.00431),
#  ('χροιά', 0.00431),
#  ('μήτρα', 0.00431),
#  ('πρόσωπον', 0.00431),
#  ('γονή', 0.00431),
#  ('δεῖ', 0.00431),
#  ('μεμιγμένα', 0.00287),
#  ('φανερός', 0.00287),
#  ('ἀποκρίνω', 0.00287),
#  ('θερμός', 0.00287),
#  ('παχύς', 0.00287),
#  ('μέρος', 0.00287),
#  ('φλέψ', 0.00287),
#  ('ὑγιαίνω', 0.00287),
#  ('ὅδε', 0.00287),
#  ('πρόφασις', 0.00287),
#  ('μετέωρος', 0.00287),
#  ('πνεῦμα', 0.00287),
#  ('ῥεῦμα', 0.00287),
#  ('πάθος', 0.00287),
#  ('δυνατός', 0.00287),
#  ('Θάσος', 0.00287),
#  ('γυνή', 0.00287),
#  ('οἶδα', 0.00287),
#  ('ὁράω', 0.00287),
#  ('οἷος', 0.00287),
#  ('ἡδονή', 0.00287),
#  ('καρδία', 0.00287),
#  ('ὅσος', 0.00287),
#  ('νεῦρον', 0.00287),
#  ('ἄρθρον', 0.00287),
#  ('ἰχώρ', 0.00287),
#  ('τέχνη', 0.00287),
#  ('ἀπαλλάσσω', 0.00287),
#  ('μέγας', 0.00287),
#  ('νοῦσος', 0.00287),
#  ('ἀφίημι', 0.00287),
#  ('φημί', 0.00287),
#  ('ἔξειμι', 0.00287),
#  ('σπλάγχνον', 0.00287),
#  ('θηλάζῃ', 0.00287),
#  ('γάλα', 0.00287),
#  ('ἐπίνοσον', 0.00287),
#  ('ἀσθενής', 0.00287),
#  ('σιτίον', 0.00287),
#  ('ταχύς', 0.00287),
#  ('αἰσθάνομαι', 0.00287),
#  ('ψαύω', 0.00287),
#  ('ὕπνος', 0.00287),
#  ('ἵστημι', 0.00287),
#  ('ὠχρός', 0.00287),
#  ('ὅρος', 0.00287),
#  ('γαστήρ', 0.00287),
#  ('αἴρω', 0.00287),
#  ('φυσᾶται', 0.00287),
#  ('πούς', 0.00287),
#  ('οἰδέουσι', 0.00287),
#  ('Κοίλη', 0.00287),
#  ('ἀειδής', 0.00287),
#  ('ἐπιμήνιος', 0.00287),
#  ('κρύπτω', 0.00287),
#  ('ἐγγίγνομαι', 0.00287),
#  ('ἀλύω', 0.00287),
#  ('στένω', 0.00287),
#  ('τόπος', 0.00287),
#  ('ὀχλέω', 0.00287),
#  ('κεκρημένα', 0.00144),
#  ('ἀλλήλων', 0.00144),
#  ('ἑωυτοῖς', 0.00144),
#  ('θέρμος', 0.00144),
#  ('ἐνίημι', 0.00144),
#  ('ἑκάτερος', 0.00144),
#  ('καιρός', 0.00144),
#  ('ἐπιγίγνομαι', 0.00144),
#  ('τάχος', 0.00144),
#  ('βοηθείης', 0.00144),
#  ('παρασκευή', 0.00144),
#  ('δεόμενον', 0.00144),
#  ('πέπων', 0.00144),
#  ('δριμύτης', 0.00144),
#  ('ἀπηλλαγμένα', 0.00144),
#  ('παύω', 0.00144),
#  ('κοιμάω', 0.00144),
#  ('ἄφωνος', 0.00144),
#  ('ἀπόληψις', 0.00144),
#  ('αἰτία', 0.00144),
#  ('προπυριῶντα', 0.00144),
#  ('φλεβοτομέειν', 0.00144),
#  ('ἀρχῇσιν', 0.00144),
#  ('διαλύηται', 0.00144),
#  ('ἐμπεπλασμένα', 0.00144),
#  ('οὖς', 0.00144),
#  ('ῥίς', 0.00144),
#  ('πτυελισμὸς', 0.00144),
#  ('γόνυ', 0.00144),
#  ('βάρος', 0.00144),
#  ('ὄγκος', 0.00144),
#  ('ἔθος', 0.00144),
#  ('πότος', 0.00144),
#  ('Ἀφροδίσιος', 0.00144),
#  ('φροντίς', 0.00144),
#  ('ἀγρυπνία', 0.00144),
#  ('θώραξ', 0.00144),
#  ('φρήν', 0.00144),
#  ('ἀνακαθίζειν', 0.00144),
#  ('ἥκιστος', 0.00144),
#  ('προσκλινέσθωσαν', 0.00144),
#  ('καθίζοντα', 0.00144),
#  ('ἀνατρίβω', 0.00144),
#  ('δυσάνιος', 0.00144),
#  ('ἄγρυπνος', 0.00144),
#  ('ἀπόσιτος', 0.00144),
#  ('διψώδης', 0.00144),
#  ('ἀσώδης', 0.00144),
#  ('δελεάρκεος', 0.00144),
#  ('κατάκειμαι', 0.00144),
#  ('λεῖος', 0.00144),
#  ('φρικώδης', 0.00144),
#  ('ὀξύς', 0.00144),
#  ('ἀπιθύνω', 0.00144),
#  ('προτέρῃσιν', 0.00144),
#  ('ἐπιδέσεσι', 0.00144),
#  ('κνησμός', 0.00144),
#  ('ἕλκωσις', 0.00144),
#  ('μηδείς', 0.00144),
#  ('ὑποπτεύω', 0.00144),
#  ('ἐπιδεδέσθαι', 0.00144),
#  ('νάρθηξ', 0.00144),
#  ('ἦθος', 0.00144),
#  ('φιλοπονίη', 0.00144),
#  ('ζητέω', 0.00144),
#  ('μελετέων', 0.00144),
#  ('δυσοργησίαι', 0.00144),
#  ('ἐπιθυμία', 0.00144),
#  ('συγκυρία', 0.00144),
#  ('γνώμη', 0.00144),
#  ('ὄμμα', 0.00144),
#  ('ἀκοή', 0.00144),
#  ('φόβος', 0.00144),
#  ('αἰσχύνη', 0.00144),
#  ('ὀργή', 0.00144),
#  ('ὑπακούω', 0.00144),
#  ('ἕκαστος', 0.00144),
#  ('πρᾶξις', 0.00144),
#  ('ἱδρώς', 0.00144),
#  ('παλμὸς', 0.00144),
#  ('δύναμις', 0.00144),
#  ('χλωρός', 0.00144),
#  ('χρῶμα', 0.00144),
#  ('χρόνιος', 0.00144),
#  ('ἴκτεροί', 0.00144),
#  ('λίθος', 0.00144),
#  ('γῆ', 0.00144),
#  ('τρώξιος', 0.00144),
#  ('ὑποχόνδρια', 0.00144),
#  ('τουτέοισι', 0.00144),
#  ('σάρξ', 0.00144),
#  ('προστεταμένα', 0.00144),
#  ('σύνδεσμος', 0.00144),
#  ('ξυμβολαὶ', 0.00144),
#  ('κινεομένων', 0.00144),
#  ('ἐγκυκλέονται', 0.00144),
#  ('ὑπόφορόν', 0.00144),
#  ('θαλάμη', 0.00144),
#  ('καταγγέλλω', 0.00144),
#  ('διοιγομένων', 0.00144),
#  ('κεκτημένοισίν', 0.00144),
#  ('ἐπιπονέω', 0.00144),
#  ('χρεομένοισιν', 0.00144),
#  ('ὀνηισταὶ', 0.00144),
#  ('ἰδιώτῃσι', 0.00144),
#  ('ξυνός', 0.00144),
#  ('ἀγαθός', 0.00144),
#  ('μεταχειριζομένοισι', 0.00144),
#  ('ἰατρός', 0.00144),
#  ('δεῖνα', 0.00144),
#  ('θιγγάνω', 0.00144),
#  ('ἀηδέων', 0.00144),
#  ('ἀλλότριος', 0.00144),
#  ('ξυμφορῇσιν', 0.00144),
#  ('ἴδιος', 0.00144),
#  ('καρπόω', 0.00144),
#  ('νοσέοντες', 0.00144),
#  ('κακός', 0.00144),
#  ('θάνατος', 0.00144),
#  ('καλέω', 0.00144),
#  ('νόσος', 0.00144),
#  ('καθημέρην', 0.00144),
#  ('μέσος', 0.00144),
#  ('στόμα', 0.00144),
#  ('πικρός', 0.00144),
#  ('ἄσιτος', 0.00144),
#  ('μεθίημι', 0.00144),
#  ('τρόπος', 0.00144),
#  ('δύο', 0.00144),
#  ('ἀνάγκη', 0.00144),
#  ('περισσός', 0.00144),
#  ('πρότερος', 0.00144),
#  ('λόγος', 0.00144),
#  ('ἀναφέρω', 0.00144),
#  ('θέρμη', 0.00144),
#  ('δύναμαι', 0.00144),
#  ('κρίσις', 0.00144),
#  ('ἄπορος', 0.00144),
#  ('ἰσάζω', 0.00144),
#  ('πλῆθος', 0.00144),
#  ('τύχη', 0.00144),
#  ('πλέως', 0.00144),
#  ('ἔρχομαι', 0.00144),
#  ('σίνος', 0.00144),
#  ('ἐπάγω', 0.00144),
#  ('βληχρός', 0.00144),
#  ('ἀσινής', 0.00144),
#  ('κόπρος', 0.00144),
#  ('πλήρης', 0.00144),
#  ('κίνδυνος', 0.00144),
#  ('αὐτέου', 0.00144),
#  ('στηρίζῃ', 0.00144),
#  ('σινεόμενον', 0.00144),
#  ('πλευρόν', 0.00144),
#  ('ξυνθερμαίνῃ', 0.00144),
#  ('ξυνετάραξε', 0.00144),
#  ('παιδίον', 0.00144),
#  ('τροφός', 0.00144),
#  ('καθαρός', 0.00144),
#  ('χολώδης', 0.00144),
#  ('πονηρός', 0.00144),
#  ('κοῦφος', 0.00144),
#  ('ἀνοιδέω', 0.00144),
#  ('θερμαινόμενα', 0.00144),
#  ('πληρόω', 0.00144),
#  ('πέσσω', 0.00144),
#  ('πεσσόμενα', 0.00144),
#  ('διαχωρέω', 0.00144),
#  ('ὀπώρα', 0.00144),
#  ('ἀκρόδρυα', 0.00144),
#  ('ἀσθενέω', 0.00144),
#  ('βεβρωκότος', 0.00144),
#  ('ὐλίγην', 0.00144),
#  ('σπᾷ', 0.00144),
#  ('στενός', 0.00144),
#  ('εἴσειμι', 0.00144),
#  ('μαίνομαι', 0.00144),
#  ('εὐφρόσυνος', 0.00144),
#  ('γέλως', 0.00144),
#  ('παιδιή', 0.00144),
#  ('ἀνία', 0.00144),
#  ('δυσφροσύναι', 0.00144),
#  ('κλαυθμός', 0.00144),
#  ('ἰητρικῆς', 0.00144),
#  ('ἀφαιρέοντα', 0.00144),
#  ('ἡρμοσμένης', 0.00144),
#  ('γλῶσσα', 0.00144),
#  ('συμφωνίῃ', 0.00144),
#  ('τέρψις', 0.00144),
#  ('ἀνάρμοστος', 0.00144),
#  ('κλείω', 0.00144),
#  ('τύπτοντος', 0.00144),
#  ('δείδω', 0.00144),
#  ('φοβερός', 0.00144),
#  ('ἐτεός', 0.00144),
#  ('φρονέοντας', 0.00144),
#  ('καθεύδω', 0.00144),
#  ('ἐγρηγοροῦσα', 0.00144),
#  ('γιγνώσκω', 0.00144),
#  ('καθορῇ', 0.00144),
#  ('ὁρατός', 0.00144),
#  ('διακούει', 0.00144),
#  ('ἀκουστός', 0.00144),
#  ('βαδίζω', 0.00144),
#  ('ἐνθυμέεται', 0.00144),
#  ('ὁκόσαι', 0.00144),
#  ('ὑπηρεσία', 0.00144),
#  ('διαπρήσσεται', 0.00144),
#  ('ἥδομαι', 0.00144),
#  ('σιτίοισιν', 0.00144),
#  ('σκέλος', 0.00144),
#  ('βαρύνοιτο', 0.00144),
#  ('μετηλλαγμένη', 0.00144),
#  ('φλέγμα', 0.00144),
#  ('θυμαίνει', 0.00144),
#  ('νέος', 0.00144),
#  ('δέρμα', 0.00144),
#  ('ἀλλοχροέει', 0.00144),
#  ('ὁποῖος', 0.00144),
#  ('σίδιον', 0.00144),
#  ('ὀφθαλμός', 0.00144),
#  ('ὠχροὶ', 0.00144),
#  ('θρίξ', 0.00144),
#  ('χνόος', 0.00144),
#  ('ὕπειμι', 0.00144),
#  ('ῥῖγος', 0.00144),
#  ('ἐπιλαμβάνω', 0.00144),
#  ('οὐρέει', 0.00144),
#  ('ὑφίστημι', 0.00144),
#  ('ὕπωχρον', 0.00144),
#  ('νῆστις', 0.00144),
#  ('μύζω', 0.00144),
#  ('προσφθέγξηται', 0.00144),
#  ('ἐρωτάω', 0.00144),
#  ('ἄσις', 0.00144),
#  ('ἀνέχω', 0.00144),
#  ('ἀκροώμενος', 0.00144),
#  ('ἀναπρησθῶσιν', 0.00144),
#  ('τουτέου', 0.00144),
#  ('ἀσθενέει', 0.00144),
#  ('ἀνίστημι', 0.00144),
#  ('προέρχομαι', 0.00144),
#  ('ὀρθόπνοια', 0.00144),
#  ('ἴσχω', 0.00144),
#  ('δύσελπις', 0.00144),
#  ('ἀποκαθαίρηται', 0.00144),
#  ('χολώδεός', 0.00144),
#  ('κύουσαν', 0.00144),
#  ('πτισάνη', 0.00144),
#  ('χυλός', 0.00144),
#  ('δίδωμι', 0.00144),
#  ('ῥόος', 0.00144),
#  ('ἐπιπάσσων', 0.00144),
#  ('ἐρυθρός', 0.00144),
#  ('συκάμινος', 0.00144),
#  ('ῥοφεέτω', 0.00144),
#  ('ἀγρησθῶσιν', 0.00144),
#  ('σμαραγέω', 0.00144),
#  ('τουτέῳ', 0.00144),
#  ('ἀσθμαίνει', 0.00144),
#  ('ἀφρίζω', 0.00144),
#  ('ἔγρηται', 0.00144),
#  ('ὀρθοπνοίη', 0.00144),
#  ('ἀθυμέει', 0.00144),
#  ('πνίγω', 0.00144),
#  ('ἕλκω', 0.00144),
#  ('κύστις', 0.00144),
#  ('ἄλγ*', 0.00144),
#  ('χείρ', 0.00144),
#  ('προΐενται', 0.00144),
#  ('δέχομαι', 0.00144),
#  ('φακός', 0.00144),
#  ('ἀείρω', 0.00144),
#  ('ἀλκυόνιον', 0.00144),
#  ('κονιορτός', 0.00144),
#  ('κηρωτῇ', 0.00144),
#  ('ὑγρῇ', 0.00144),
#  ('ῥοδίνου', 0.00144),
#  ('ὑποχρίειν', 0.00144),
#  ('ὕδωρ', 0.00144),
#  ('προσχέειν', 0.00144),
#  ('ἄνω', 0.00144),
#  ('ἕλξιν', 0.00144),
#  ('ἀδένας', 0.00144),
#  ('ῥοή', 0.00144),
#  ('σύμμετρος', 0.00144),
#  ('ἐγκρατής', 0.00144),
#  ('ἀδένες', 0.00144),
#  ('οἰκεῖος', 0.00144),
#  ('παραγινόμενον', 0.00144),
#  ('ἐνοχλέω', 0.00144),
#  ('μήτις', 0.00144),
#  ('ἥλιος', 0.00144),
#  ('αὐγή', 0.00144),
#  ('τεμνομένους', 0.00144),
#  ('ἐλάχιστος', 0.00144),
#  ('τομεύς', 0.00144),
#  ('εὑρίσκω', 0.00144),
#  ('ἄγουσαν', 0.00144),
#  ('ἐπιπροσθέω', 0.00144),
#  ('ἑλκομένην', 0.00144),
#  ('νοτίς', 0.00144),
#  ('ξυναγομένῳ', 0.00144),
#  ('ἐνοχλεῦντα', 0.00144),
#  ('ὑπολείπω', 0.00144),
#  ('ἀφαιρέω', 0.00144),
#  ('συμπάθησις', 0.00144),
#  ('συμπαθείης', 0.00144),
#  ('καταύδησις', 0.00144),
#  ('θεομαχεῖς', 0.00144),
#  ('κόσμος', 0.00144),
#  ('χαρά', 0.00144),
#  ('ἐκβάλλω', 0.00144),
#  ('ἀρηρυίῃ', 0.00144),
#  ('βεβαίῃ', 0.00144),
#  ('ἐκλελησμένοι', 0.00144),
#  ('συνόχωκα', 0.00144),
#  ('ἐμπιπτόντων', 0.00144),
#  ('ποθεῦντες', 0.00144),
#  ('διζήμενοι', 0.00144),
#  ('ξυμφέροντα', 0.00144),
#  ('ἐγκαλινδεῦνται', 0.00144),
#  ('ξυμφορῆσιν', 0.00144),
#  ('δοκέω', 0.00144),
#  ('γελῇν', 0.00144),
#  ('ἐξευρίσκω', 0.00144),
#  ('ἐθέλω', 0.00144)]

# %%
tfidf_lists = []
for key in pain_words_sents.keys():
    tfidf_lists.append(pain_words_sents[key]["TFIDF"][:20])

# %%
tfidf_20_df = pd.DataFrame(tfidf_lists).T#  
tfidf_20_df.columns=pain_words_sents.keys()
tfidf_20_df
# Out:
#           λύπ*_all_sents       ἄλγ*_all_sents      ὀδύν*_all_sents  \
# 0         (εἰμί, 0.0804)     (κεφαλή, 0.0629)       (ἔχω, 0.06531)
# 1    (ἄνθρωπος, 0.06375)   (πυρετός, 0.06213)   (πυρετός, 0.05324)
# 2       (αὐτός, 0.05494)     (ὀσφῦς, 0.05419)   (γίγνομαι, 0.0528)
# 3        (σῶμα, 0.05242)     (ὀδύν*, 0.05028)    (γαστήρ, 0.04895)
# 4    (γίγνομαι, 0.04959)       (ἔχω, 0.04635)     (κεφαλή, 0.0436)
# 5    (συμβαίνω, 0.04236)     (γαστήρ, 0.0451)      (ἴσχω, 0.04171)
# 6       (πολύς, 0.03877)    (κοιλία, 0.04028)      (ἰξύς, 0.03739)
# 7      (οὐδείς, 0.03875)  (γίγνομαι, 0.03874)    (παρέχω, 0.03574)
# 8         (οὗτος, 0.037)      (εἰμί, 0.03707)      (πολύς, 0.0357)
# 9       (ἐσθίω, 0.03409)      (ἴσχω, 0.02834)    (κενεών, 0.03375)
# 10     (κοιλία, 0.03357)      (ἰξύς, 0.02687)      (εἰμί, 0.03327)
# 11     (ὀλίγος, 0.03144)     (οὗτος, 0.02621)  (νειαίρην, 0.03197)
# 12    (προσήκω, 0.02968)      (σῶμα, 0.02329)      (ὀξύς, 0.03053)
# 13      (ἡμέρα, 0.02912)      (μήτρα, 0.0231)      (ἄλγ*, 0.02704)
# 14     (ἀειδής, 0.02701)   (τράχηλος, 0.0225)    (στῆθος, 0.02689)
# 15      (πόνο*, 0.02636)      (χολή, 0.02206)   (λαμβάνω, 0.02669)
# 16  (ἐξέρχομαι, 0.02628)       (αἷμα, 0.0209)      (αἷμα, 0.02613)
# 17     (χρόνος, 0.02597)   (πλευροῦ, 0.02087)      (παύω, 0.02604)
# 18  (μεμιγμένα, 0.02585)    (στῆθος, 0.02083)     (ῥῖγος, 0.02554)
# 19   (ἐπίνοσον, 0.02585)    (λαμβάνω, 0.0208)       (βήξ, 0.02484)
#
#         πόνο*_all_sents
# 0        (σῶμα, 0.0509)
# 1   (γίγνομαι, 0.04894)
# 2      (πολύς, 0.04855)
# 3       (εἰμί, 0.03569)
# 4      (ἄλλος, 0.03276)
# 5    (πυρετός, 0.03228)
# 6        (ἔχω, 0.03166)
# 7     (κοιλία, 0.03114)
# 8        (πᾶς, 0.02696)
# 9     (χρόνος, 0.02619)
# 10       (οὗτος, 0.026)
# 11    (παρέχω, 0.02514)
# 12     (σιτίον, 0.0245)
# 13      (σάρξ, 0.02264)
# 14   (ἰσχυρός, 0.02247)
# 15     (σῖτος, 0.01944)
# 16      (αἷμα, 0.01925)
# 17  (ἄνθρωπος, 0.01904)
# 18     (ἡμέρα, 0.01848)
# 19      (ὀσφῦς, 0.0183)

# %%
#set_with_dataframe(PIA_overview.add_worksheet("tfidf_20_df", 1, 1), tfidf_20_df)

# %%
column = "λύπ*_all_sents"
tfidf_words = list(set([word for wordlist in [[tup[0] for tup in tfidf_20_df[column].tolist()] for column in tfidf_20_df.columns] for word in wordlist]))

# %%
[word for word in tfidf_words if word not in terms_by_cat_dict.keys()]
# Out:
# []

# %%
words_to_code = [word for word in tfidf_words if word not in terms_by_cat_dict.keys()] 
for word in words_to_code:
    try:
        print(word, morpheus_by_lemma[word])
    except:
        print(word)

# %%
df_columns = []
tfidf_20_split = []
for column in tfidf_20_df.columns:
    tfidf_20_split.append([tup[0] for tup in tfidf_20_df[column].tolist()])
    tfidf_20_split.append([tup[1] for tup in tfidf_20_df[column].tolist()])
    df_columns.extend([column.partition("_")[0] + "_words", column.partition("_")[0] + "_TFIDFs"])

# %%
tfidf_20_split_df = pd.DataFrame(tfidf_20_split).T
tfidf_20_split_df.columns = df_columns
tfidf_20_split_df
# Out:
#    λύπ*_words λύπ*_TFIDFs ἄλγ*_words ἄλγ*_TFIDFs ὀδύν*_words ὀδύν*_TFIDFs  \
# 0        εἰμί      0.0804     κεφαλή      0.0629         ἔχω      0.06531
# 1    ἄνθρωπος     0.06375    πυρετός     0.06213     πυρετός      0.05324
# 2       αὐτός     0.05494      ὀσφῦς     0.05419    γίγνομαι       0.0528
# 3        σῶμα     0.05242      ὀδύν*     0.05028      γαστήρ      0.04895
# 4    γίγνομαι     0.04959        ἔχω     0.04635      κεφαλή       0.0436
# 5    συμβαίνω     0.04236     γαστήρ      0.0451        ἴσχω      0.04171
# 6       πολύς     0.03877     κοιλία     0.04028        ἰξύς      0.03739
# 7      οὐδείς     0.03875   γίγνομαι     0.03874      παρέχω      0.03574
# 8       οὗτος       0.037       εἰμί     0.03707       πολύς       0.0357
# 9       ἐσθίω     0.03409       ἴσχω     0.02834      κενεών      0.03375
# 10     κοιλία     0.03357       ἰξύς     0.02687        εἰμί      0.03327
# 11     ὀλίγος     0.03144      οὗτος     0.02621    νειαίρην      0.03197
# 12    προσήκω     0.02968       σῶμα     0.02329        ὀξύς      0.03053
# 13      ἡμέρα     0.02912      μήτρα      0.0231        ἄλγ*      0.02704
# 14     ἀειδής     0.02701   τράχηλος      0.0225      στῆθος      0.02689
# 15      πόνο*     0.02636       χολή     0.02206     λαμβάνω      0.02669
# 16  ἐξέρχομαι     0.02628       αἷμα      0.0209        αἷμα      0.02613
# 17     χρόνος     0.02597    πλευροῦ     0.02087        παύω      0.02604
# 18  μεμιγμένα     0.02585     στῆθος     0.02083       ῥῖγος      0.02554
# 19   ἐπίνοσον     0.02585    λαμβάνω      0.0208         βήξ      0.02484
#
#    πόνο*_words πόνο*_TFIDFs
# 0         σῶμα       0.0509
# 1     γίγνομαι      0.04894
# 2        πολύς      0.04855
# 3         εἰμί      0.03569
# 4        ἄλλος      0.03276
# 5      πυρετός      0.03228
# 6          ἔχω      0.03166
# 7       κοιλία      0.03114
# 8          πᾶς      0.02696
# 9       χρόνος      0.02619
# 10       οὗτος        0.026
# 11      παρέχω      0.02514
# 12      σιτίον       0.0245
# 13        σάρξ      0.02264
# 14     ἰσχυρός      0.02247
# 15       σῖτος      0.01944
# 16        αἷμα      0.01925
# 17    ἄνθρωπος      0.01904
# 18       ἡμέρα      0.01848
# 19       ὀσφῦς       0.0183

# %%
words = []
for key_word in key_words:
    words.extend(tfidf_20_split_df[key_word + "_words"].tolist())
tfidf_unique_words = list(set(words))
len(tfidf_unique_words)
# Out:
# 49

# %%
print(tfidf_unique_words)
# Out:
# ['ἄνθρωπος', 'σιτίον', 'πυρετός', 'ὀξύς', 'σῖτος', 'ὀδύν*', 'στῆθος', 'ἐσθίω', 'πόνο*', 'πλευροῦ', 'εἰμί', 'κεφαλή', 'ἐξέρχομαι', 'λαμβάνω', 'γαστήρ', 'σῶμα', 'μήτρα', 'ἀειδής', 'παρέχω', 'συμβαίνω', 'ἐπίνοσον', 'παύω', 'τράχηλος', 'ἡμέρα', 'γίγνομαι', 'οὗτος', 'χρόνος', 'ἔχω', 'βήξ', 'αἷμα', 'μεμιγμένα', 'πᾶς', 'ἴσχω', 'χολή', 'ὀσφῦς', 'ὀλίγος', 'σάρξ', 'ἰξύς', 'πολύς', 'προσήκω', 'ἄλγ*', 'ἰσχυρός', 'αὐτός', 'οὐδείς', 'ῥῖγος', 'κοιλία', 'νειαίρην', 'ἄλλος', 'κενεών']

# %%
#plt.rcParams['figure.figsize'] = [12, 4]
fig, axs = plt.subplots(1, 4, figsize=[12,4], tight_layout=True)

for word, ax in zip(key_words, axs):
    xcol = tfidf_20_split_df[word + "_TFIDFs"]
    ycol = tfidf_20_split_df[word + "_words"]
    actual_colors = [terms_by_col_dict[word] for word in ycol]
    sns.barplot(x=xcol, y=ycol, palette=actual_colors, ax=ax)
    ax.set(ylabel="", xlabel="terms with highest TFIDF \nwithin sentences containing \nthe term " + word)
    ax.set_xticks([0, 0.03, 0.06, 0.09])
    ax.set_xlim(0, 0.09)
plt.subplots_adjust(hspace=0.08) # top=1, bottom=0, left=0, right=1, hspace=0.08, wspace=1.2)

#plt.title("Most frequent terms in sentences containing pain-words                       ", loc="right")

markers = [plt.Line2D([0,0],[0,0],color=color, marker="s", linestyle="") for color in colors]
plt.legend(markers, term_cats, numpoints=1,  title="Term categories", bbox_to_anchor=(1, 1), loc='upper left')

# %%
sddk.write_file("public_data/PIA/tfidfs_in_sentences_20210119.png", fig, conf)
# Out:
# Your <class 'matplotlib.figure.Figure'> object has been succefully written as "https://sciencedata.dk/files/public_data/PIA/tfidfs_in_sentences_20210119.png"
